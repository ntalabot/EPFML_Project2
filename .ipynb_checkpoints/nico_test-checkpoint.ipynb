# %%
# %matplotlib inline

import os,sys
import time

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

import scipy.ndimage.morphology as morph

from sklearn.metrics import f1_score
from skimage import measure
from skimage import feature

import torch
import torch.utils.data
from torch.autograd import Variable

import image_processing as ip

# %load_ext autoreload
# %autoreload 2

# %%
PATCH_SIZE = 16
IMAGE_SIZE = 400
PATCH_NUM  = IMAGE_SIZE//PATCH_SIZE
FOREGROUND_THRESHOLD = 0.25

# %% [markdown]
# # 1 Data loading and pre-processing

# %% [markdown]
# ## 1.1 Load the data

# %%
# Directory and files name
train_dir = "training/"
tr_image_dir = train_dir + "images/"
tr_gt_dir = train_dir + "groundtruth/"

tr_image_files = sorted(os.listdir(tr_image_dir))
tr_gt_files = sorted(os.listdir(tr_gt_dir))

# Number of training samples
N = len(tr_image_files)

# Load the images and ground truth
image_train = []
gt_train = []
for i in range(N):
    image = mpimg.imread(tr_image_dir + tr_image_files[i])
    gt = mpimg.imread(tr_gt_dir + tr_gt_files[i])
    
    image_train.append(image)
    gt_train.append(gt)

# Keep only sub-set of images (or = N to use them all)
IMAGES_NUM = N

image_train = np.asarray(image_train[:IMAGES_NUM])
gt_train = np.asarray(gt_train[:IMAGES_NUM])

print(image_train.shape, gt_train.shape)
# Out:
# (100, 400, 400, 3) (100, 400, 400)

# %% [markdown]
# ### Create the labels
# Create label images (reduced and full-sized) by assigning a label to a patch of pixels in the groundtruth images
#
# 1. Reduced: size is reduced by PATCH_SIZE
# 2. Full-sized: the original size of the groundtruth image is kept (might be useless, though)

# %%
def patch_to_label(patch):
    """
    Return the label of the patch, based on FOREGROUND_THRESHOLD
    Input:
        patch: patch of a groundtruth image; size:(PATCH_SIZE, PATCH_SIZE)
    Output:
        the label of the patch (1: foreground, 0:background)
    """
    fg = np.mean(patch)
    if fg > FOREGROUND_THRESHOLD:
        return 1
    else:
        return 0

def gt_to_label(gt_image):
    """
    Return a reduced label image, with the label of each pixel patches in gt_image
    Input:
        gt_image: the groundtruth image; size:(height, width)
    Output:
        label: the label image; size:(height/PATCH_SIZE, width/PATCH_SIZE)
    """
    height, width = gt_image.shape
    label = np.zeros((height//PATCH_SIZE, width//PATCH_SIZE))
    for i in range(0, height//PATCH_SIZE):
        for j in range(0, width//PATCH_SIZE):
            patch = gt_image[i*PATCH_SIZE:(i+1)*PATCH_SIZE, j*PATCH_SIZE:(j+1)*PATCH_SIZE]
            label[i,j] = patch_to_label(patch)
    return label

def gt_to_label_image(gt_image):
    """
    Return a full-sized label image, with the label of each pixel patches in gt_image
    Input:
        gt_image: the groundtruth image; size:(height, width)
    Output:
        label: the label image; size:(height, width)
    """
    height, width = gt_image.shape
    label = np.zeros((height, width))
    for i in range(0, height, PATCH_SIZE):
        for j in range(0, width, PATCH_SIZE):
            patch = gt_image[i:i+PATCH_SIZE, j:j+PATCH_SIZE]
            label[i:i+PATCH_SIZE, j:j+PATCH_SIZE] = patch_to_label(patch)
    return label

label_train = np.asarray([gt_to_label(gt_train[i]) for i in range(IMAGES_NUM)])
label_train_image = np.asarray([gt_to_label_image(gt_train[i]) for i in range(IMAGES_NUM)])
print(label_train.shape, label_train_image.shape)
# Out:
# (100, 25, 25) (100, 400, 400)

# %%
# Test the loading by showing image, ground truth & label
img_num = 0
# Show the image and its groundtruth
plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(image_train[img_num])
plt.title("Image")
plt.subplot(132)
plt.imshow(gt_train[img_num], cmap='gray')
plt.title("Ground truth")
plt.subplot(133)
plt.imshow(label_train[img_num], cmap='gray')
plt.title("Label")
# Out:
# Text(0.5,1,'Label')

# %% [markdown]
# **REQUIRED: Computation of the ratio Road-Background**

# %%
road_labels = (label_train == 1).sum()
background_labels = (label_train == 0).sum()
ROAD_RATIO = float(road_labels) / float(road_labels + background_labels)
print(
    "Road labels: %d" % road_labels + "\n" +
    "Background labels: %d" % background_labels + "\n" +
    "Proportion of road: %.2f %%" % (ROAD_RATIO*100)
)
# Out:
# Road labels: 16191
# Background labels: 46309
# Proportion of road: 25.91 %

# %% [markdown]
# ## 1.2 Pre-process the data
# Do pre-processing here, e.g. edge detection, etc.
# Can add the results as an additional channel in the training images.

# %%
# Edge detection
x_edges = np.zeros(image_train.shape)

# Loop on images and color
for im in range(image_train.shape[0]):
    for col in range(3):
        x_edges[im,:,:,col] = feature.canny(image_train[im,:,:,col], sigma=3.0)

# Average the edges over the channels:
x_edges = x_edges.mean(axis=-1)

# First line: with edge detection, Second: without
# x_train = np.concatenate((image_train, x_edges[:,:,:,np.newaxis]), axis=-1)
x_train = image_train.copy()
y_train = label_train.copy()
print(x_train.shape, y_train.shape)
# Out:
# (100, 400, 400, 3) (100, 25, 25)

# %%
img_num = 0

plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(x_train[img_num,:,:,:3])
plt.title("RGB Image")
plt.subplot(132)
plt.imshow(x_train[img_num,:,:,-1], cmap='gray')
plt.title("Edge detection")
# Out:
# Text(0.5,1,'Edge detection')

# %% [markdown]
# ## 1.3 Window extraction
# Define functions to extract a window around each patch of pixels in x_train.

# %%
def get_window(image, window_size, i, j):
    """
    Extract a window in image, with the top left corner at (i,j) (mirror boundary conditions apply)
    Note that (i,j) = (y,x) in pixel coordinate (assuming image conventions)
    Input:
        image: the image array; size:(height, width, num_channel)
        window_size: size of the window to extract
        i: the row-coordinate of the window's top-left corner
        j: the col-coordinate of the window's top-left corner
    Output:
        window: the window array; size:(window_size, window_size, num_channel)
    """
    window = np.zeros((window_size, window_size, image.shape[2]))
    for ii in range(window_size):
        for jj in range(window_size):
            window[ii,jj,:] = ip.get_pixel(image, i + ii, j + jj)
    return window

def shift_window(image, window, i, j, stride=1):
    """
    Shift the window to the right by 'stride' pixels on the image (mirror boundary conditions apply)
    Note that (i,j) = (y,x) in pixel coordinate (assuming image conventions)
    Input:
        image: the image array; size:(height, width, num_channel)
        window: the window array; size:(window_size, window_size, num_channel)
        i: the row-coordinate of the window's top-left corner
        j: the col-coordinate of the window's top-left corner
        stride: the number of pixel to move the window (default: 1)
    Output:
        new_window: the shifted window; size:(window_size, window_size, num_channel)
    """
    window_size = window.shape[0]
    new_window = np.zeros(window.shape)
    new_i = i
    new_j = j + stride

    # If stride is too big, so no overlap between windows, return a new window
    if stride >= window_size:
        return get_window(image, window_size, new_i, new_j)
    
    # Else, delete first 'stride' columns, and insert 'stride' new ones at the end of the window
    new_window[:,:window_size-stride,:] = window[:,stride:,:]
    for ii in range(window_size):
        for jj in range(window_size-stride, window_size):
            new_window[ii,jj,:] = ip.get_pixel(image, new_i + ii, new_j + jj)
    return new_window
    

def image_to_windows(image, window_size=PATCH_SIZE):
    """
    Return the windows around each patch of pixels of the given image (mirror boundary conditions apply)
    Input:
        image: the image array; size:(height, width, num_channel)
        window_size: size of the windows, should be even and bigger than PATCH_SIZE (default: PATCH_SIZE)
    Output:
        windows: the windows array; size:(height*width/PATCH_SIZE**2, window_size, window_size, num_channel)
    """
    height, width, _ = image.shape
    # Offset between top-left corners of patch and window
    offset = -(window_size - PATCH_SIZE)//2
    windows_list = []
    
    # Get first window of the row, then loop on the columns
    for i in range(offset, height+offset, PATCH_SIZE):
        window = get_window(image, window_size, i, offset)
        windows_list.append(window)
        for j in range(offset, width-PATCH_SIZE+offset, PATCH_SIZE):
            window = shift_window(image, window, i, j, stride=PATCH_SIZE)
            windows_list.append(window)
    
    windows = np.asarray(windows_list)
    return windows

def extract_windows(images, window_size=PATCH_SIZE):
    """
    Return the windows around each patch of pixels of every images (mirror boundary conditions apply)
    Input:
        images: the images array; size:(num_images, height, width, num_channel)
        window_size: size of the windows, should be even and bigger than PATCH_SIZE (default: PATCH_SIZE)
    Output:
        windows: the windows array; size:(num_images, height*width/PATCH_SIZE**2, window_size, window_size, num_channel)
    """
    windows = []
    for i in range(0, images.shape[0]):
        windows.append(image_to_windows(images[i], window_size=window_size))
    return np.asarray(windows)

# %%
# Test neighbourhood by showing image and pixel's neighbourhood
# Can check if mirror boundary works too
wind = get_window(x_train[img_num], 200, 250, -50)
shifted = shift_window(x_train[img_num], wind, 250, -50, stride=50)

plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(x_train[img_num])
plt.title("Image")
plt.subplot(132)
plt.imshow(wind)
plt.title("Window")
plt.subplot(133)
plt.imshow(shifted)
plt.title("Shifted")
# Out:
# Text(0.5,1,'Shifted')

# %%
# Test windows extraction
# %timeit extract_windows(x_train, window_size=50)

# %%
# Test windows extraction
# test_windows = extract_windows(x_train, window_size=50)
# print(test_windows.shape)

# plt.figure(figsize=(10,10))
# plt.subplot(121)
# plt.imshow(test_windows[0][0])
# plt.subplot(122)
# plt.imshow(test_windows[0][1])

# %% [markdown]
# ## 1.4 Additional functions

# %%
def split_data(x, y, ratio, seed=1):
    """
    split the dataset based on the split ratio. If ratio is 0.8
    you will have 80% of your data set dedicated to training
    and the rest dedicated to testing
    """
    # set seed
    np.random.seed(seed)

    indices = np.random.permutation(y.shape[0])
    train_size = int(y.shape[0] * ratio)

    x_train, y_train = x[indices[:train_size]], y[indices[:train_size]]
    x_test, y_test = x[indices[train_size:]], y[indices[train_size:]]
    return x_train, y_train, x_test, y_test

# %% [markdown]
# # 2 Learning

# %% [markdown]
# ## 2.1 Definition
# 1. Datasets and Dataloaders
# 2. Model
# 3. Loss function
# 4. Optimizer

# %%
class NN(torch.nn.Module):
    """
    Class implementing a Neural Network as a PyTorch Module
    """
    
    def __init__(self, window_size, num_channel):
        """
        Initialize the neural network, the input size depends on how many pixels are fed to it
        Input:
            window_size: size of the window around each pixel patch (should be a multiple of 4)
            num_channel: number of channels in the image patches (default: 3, i.e. RGB)
        """
        super(NN, self).__init__()
        
        self.conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(num_channel, 12, kernel_size=5, padding=2),
            torch.nn.ELU(alpha=1.0),
            #torch.nn.ReLU(),
            #torch.nn.BatchNorm2d(12),
            torch.nn.MaxPool2d(2)
        )
        self.conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(12, 32, kernel_size=3, padding=1),
            torch.nn.ELU(alpha=1.0),
            #torch.nn.ReLU(),
            #torch.nn.BatchNorm2d(32),
            torch.nn.MaxPool2d(2)
        )
        self.conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(32, 48, kernel_size=3),
            torch.nn.ELU(alpha=1.0),
            #torch.nn.ReLU(),
            #torch.nn.BatchNorm2d(48),
            torch.nn.MaxPool2d(2)
        )
        self.fc1 = torch.nn.Sequential(
            torch.nn.Linear(48 * ((window_size-8)//8)**2, 32),
            torch.nn.ELU(alpha=1.0),
            #torch.nn.ReLU(),
            #torch.nn.BatchNorm2d(32),
        )
        self.fc2 = torch.nn.Sequential(
            torch.nn.Linear(32, 64),
            torch.nn.ELU(alpha=1.0),
            #torch.nn.ReLU(),
            #torch.nn.BatchNorm2d(64),
        )
        self.fcout = torch.nn.Sequential(
            torch.nn.Linear(64, 1)
            # The Sigmoid activation is considered with the loss itself (Binary Cross-Entropy with Logits)
        )

    def forward(self, x):
        """
        Perform a foward pass, by appling the model to the input x
        Input:
            x: an image window; size:(window_size, window_size, num_channel)
        Output:
            y_pred: the predicted label of the patch
        """
        h1 = self.conv1(x)
        h2 = self.conv2(h1)
        h3 = self.conv3(h2)
        h3 = h3.view(h3.size(0), -1)
        h4 = self.fc1(h3)
        h5 = self.fc2(h4)
        y_pred = self.fcout(h5)
        return y_pred

# %%
class roadDataset(torch.utils.data.Dataset):
    """
    Road segmentation dataset
    """
    
    def __init__(self, windows, labels=None, train=True):
        """
        Initialize the dataset with the given windows and labels
        Input:
            windows: the windows array; size:(num_window, window_size, window_size, num_channel)
            labels: the label array; size:(num_window,)
                    (default: None) -> reserved for test sets
            train: is this dataset a train set? i.e., does it have labels? (default: True)
            
        """
        # From (NxHxWxC) Numpy array, to (NxCxHxW) PyTorch tensor
        windows = windows.transpose((0,3,1,2))
        self.windows = torch.from_numpy(windows).double()
        
        self.train = train
        if self.train:
            self.labels = torch.from_numpy(labels).view(-1,1).double()
        
    def __len__(self):
        return self.windows.shape[0]
    
    def __getitem__(self, idx):
        if self.train:
            if (self.labels[idx] == 0).numpy():
                weight = ROAD_RATIO
            else:
                weight = 1. - ROAD_RATIO
            return self.windows[idx], self.labels[idx], weight
        else:
            return self.windows[idx], 0, 1

# %%
seed = 1
np.random.seed(seed=seed)
torch.manual_seed(seed)
ratio = 0.8
# Hyper-parameters
num_epoch = 5
batch_size = 25
learning_rate = 1e-3
window_size = 48

# Extract windows for each patches
start = time.time()
tx = extract_windows(x_train, window_size=window_size)
ty = y_train.reshape((y_train.shape[0], -1))
end = time.time()
print("Created windows in %.3f seconds." % (end-start))
# Split data, and creat dataset loader
x_tr, y_tr, x_te, y_te = split_data(tx.reshape((-1,window_size,window_size,tx.shape[-1])),
                                    ty.ravel(),
                                    ratio, seed=seed)
train_dataset = roadDataset(x_tr, y_tr)
test_dataset = roadDataset(x_te, y_te)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

network = NN(window_size, tx.shape[-1]).double()
loss = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
# Out:
# Created windows in 137.073 seconds.

# %% [markdown]
# ## 2.2 Train the network

# %%
def train(train_loader, model, loss_fn, optimizer, num_epoch, verbose=False):
    """
    Train the neural networks with the given images and their labels.
    Input:
        train_loader: the PyTorch data loader with the training dataset
        model: the PyTorch model (the neural network)
        loss_fn: the PyTorch loss function
        optimizer: the PyTorch optimizer
        num_epoch: the number of epoch <=> number of pass over the data
        verbose: boolean to choose to print or not the current status (default: False)
    """
    # Change model to 'train' mode (useful for Dropout and BatchNormalization)
    model.train()
    for epoch in range(num_epoch):
        epoch_loss = []
        for i, (images, labels, weights) in enumerate(train_loader):
            images = Variable(images)
            labels = Variable(labels)
            
            preds = model(images)
            loss_fn.weight = weights
            loss = loss_fn(preds, labels)
            
            optimizer.zero_grad()  
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.data[0])
            if (i+1) % 100 == 0 and verbose:
                print ('Epoch [%2d/%2d], Batch [%3d], Loss: %.4f' 
                       %(epoch+1, num_epoch, i+1, loss.data[0]))
        if verbose:
            print("Epoch [%2d/%2d] Loss: %.4f" % (epoch+1, num_epoch, np.asarray(epoch_loss).mean()))

# %%
start = time.time()
train(
    train_loader=train_loader,
    model=network,
    loss_fn=loss,
    optimizer=optimizer,
    num_epoch=num_epoch,
    verbose=True
)
end = time.time()
print("Trained network in %.3f seconds." % (end - start))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-120337c846aa> in <module>()
#       1 start = time.time()
#       2 train(
# ----> 3     train_loader=train_loader,
#       4     model=network,
#       5     loss_fn=loss,
#
# NameError: name 'train_loader' is not defined

# %% [markdown]
# ## 2.3 Test the predictions

# %%
def test(test_loader, model, verbose=False):
    """
    Test the neural networks with the given images and their labels.
    Input:
        test_loader: the PyTorch data loader with the testing dataset
        model: the PyTorch model (the neural network)
        verbose: boolean to choose to print (default: False)
    Output:
        f1_test: the F1-score on the given test set
    """
    # Change model to 'eval' mode (useful for Dropout and BatchNormalization)
    model.eval()
    
    correct = 0
    total = 0
    prediction = []
    true_label = []
    
    for images, labels, _ in test_loader:
        images = Variable(images)
        preds = model(images).data
        
        preds[preds >= 0.5] = 1
        preds[preds < 0.5] = 0
        
        total += labels.size(0)
        correct += (preds == labels).sum()
        prediction += preds.numpy().ravel().tolist()
        true_label += labels.numpy().ravel().tolist()
    
    prediction = np.asarray(prediction).ravel().astype(int)
    true_label = np.asarray(true_label).ravel().astype(int)
    f1_test = f1_score(true_label, prediction)
    if verbose:
        print("Correct: %d/%d" % (correct, total))
        print("Accuracy: %.2f %%" % (100 * correct / total))
        print("-----------------")
        print("F1-score: %.4f" % f1_test)
    return f1_test

# %%
f1_test = test(
    test_loader=test_loader,
    model=network,
    verbose=True
)
# Out:
# Correct: 10596/12500
# Accuracy: 84.77 %
# -----------------
# F1-score: 0.6959

# %% [markdown]
# ## 2.4 Cross-validation
# Repeat the previous steps with cross-validation

# %%
def build_k_indices(num_indices, k_fold, seed=1):
    """
    Build an array containing the indices of k groups for the data
    Input:
        num_indices: the number of indices to group
        k_fold: the number of groups/fold
        seed: the random seed (default: 1)
    Output:
        k_indices: array containing the k groups of indices
    """
#     np.random.seed(seed)
    interval = int(num_indices / k_fold)
    indices = np.random.permutation(num_indices)
    k_indices = [indices[k * interval: (k + 1) * interval]
                 for k in range(k_fold)]
    return np.array(k_indices)

def cross_validation(x_train, y_train, window_size, learning_rate, num_epoch, batch_size, num_fold, seed=1, verbose=False):
    """
    Performs a k-fold cross validation on the training data, and returns the F1-scores of the training and testing sets
    Input:
        x_train: the array containing the satellite images; size:(IMAGES_NUM, height, width, num_channel)
        y_train: the array containing the label images; size:(IMAGES_NUM, height/PATCH_SIZE, width/PATCH_SIZE)
        window_size: the window size to test
        learning_rate: the learning rate for the optimization algorithm
        num_epoch: the number of epoch <=> number of pass over the data
        batch_size: the size of one batch for a step of the optimizer
        num_fold: the number of fold for the k-fold cross validation
        seed: the random seed (default: 1), set to None if you do not want to initialize seeds here
        verbose: boolean to choose to print (default: False)
    Output:
        f1_train: an array containing the F1-score of the training sets
        f1_test: an array containing the F1-score of the testing sets
    """
    f1_train = np.zeros(num_fold)
    f1_test = np.zeros(num_fold)
    if seed is not None:
        np.random.seed(seed)
        torch.manual_seed(seed)
    
    # Extract windows for each patches
    tx = extract_windows(x_train, window_size=window_size)
    tx = tx.reshape((-1,window_size,window_size,tx.shape[-1]))
    ty = y_train.reshape((y_train.shape[0], -1))
    ty = ty.ravel()
    k_indices = build_k_indices(ty.shape[0], num_fold, seed=seed)
    
    for k in range(num_fold):
        if verbose:
            print("\nFold [%d/%d]: " % (k+1, num_fold) + "-" * 20)
        # Split data, and creat dataset loaders
        x_tr = tx[k_indices[np.arange(len(k_indices))!=k].ravel()]
        y_tr = ty[k_indices[np.arange(len(k_indices))!=k].ravel()]
        x_te = tx[k_indices[k]]
        y_te = ty[k_indices[k]]
        
        train_dataset = roadDataset(x_tr, y_tr)
        test_dataset = roadDataset(x_te, y_te)
        train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                   batch_size=batch_size, 
                                                   shuffle=True)
        test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                                  batch_size=batch_size, 
                                                  shuffle=False)
        # Create model, loss, and optimizer
        network = NN(window_size, tx.shape[-1]).double()
        loss = torch.nn.BCEWithLogitsLoss()
        optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)

        # Train the network
        train(
            train_loader=train_loader,
            model=network,
            loss_fn=loss,
            optimizer=optimizer,
            num_epoch=num_epoch,
            verbose=True
        )

        # Compute the F1-score for the train and test set respectively
        f1_train[k] = test(
            test_loader=train_loader,
            model=network,
            verbose=False
        )
        f1_test[k] = test(
            test_loader=test_loader,
            model=network,
            verbose=False
        )
        if verbose:
            print("F1-scores: train = %.4f ; test = %.4f" % (f1_train[k], f1_test[k]))
    return f1_train, f1_test

# %%
start = time.time()
f1_train, f1_test = cross_validation(
    x_train=x_train,
    y_train=y_train,
    window_size=32,
    learning_rate=1e-3,
    num_epoch=7,
    batch_size=25,
    num_fold=4,
    seed=2,
    verbose=True
)
end = time.time()
print("\nCross-validation effectuated in %.3f seconds" % (end-start))
print("F1 training: %.4f +/- %.4f" % (f1_train.mean(), f1_train.std()))
print("F1 testing:  %.4f +/- %.4f" % (f1_test.mean(), f1_test.std()))

plt.figure()
plt.plot([1,2,3,4], f1_train)
plt.plot([1,2,3,4], f1_test)
plt.legend(["Train", "Test"]), plt.show, plt.ylim([0, 1])
# Out:
# Fold [1/4]: --------------------
# Epoch [ 1/ 7], Batch [100], Loss: 0.1887
# Epoch [ 1/ 7], Batch [200], Loss: 0.3782
# Epoch [ 1/ 7], Batch [300], Loss: 0.1851
# Epoch [ 1/ 7], Batch [400], Loss: 0.2218
# Epoch [ 1/ 7], Batch [500], Loss: 0.2085
# Epoch [ 1/ 7], Batch [600], Loss: 0.1378
# Epoch [ 1/ 7], Batch [700], Loss: 0.2117
# Epoch [ 1/ 7], Batch [800], Loss: 0.0933
# Epoch [ 1/ 7], Batch [900], Loss: 0.1198
# Epoch [ 1/ 7], Batch [1000], Loss: 0.1372
# Epoch [ 1/ 7], Batch [1100], Loss: 0.0783
# Epoch [ 1/ 7], Batch [1200], Loss: 0.1237
# Epoch [ 1/ 7], Batch [1300], Loss: 0.2893
# Epoch [ 1/ 7], Batch [1400], Loss: 0.1327
# Epoch [ 1/ 7], Batch [1500], Loss: 0.2625
# Epoch [ 1/ 7], Batch [1600], Loss: 0.0944
# Epoch [ 1/ 7], Batch [1700], Loss: 0.1416
# Epoch [ 1/ 7], Batch [1800], Loss: 0.1224
# Epoch [ 1/ 7] Loss: 0.1648
# Epoch [ 2/ 7], Batch [100], Loss: 0.1625
# Epoch [ 2/ 7], Batch [200], Loss: 0.0944
# Epoch [ 2/ 7], Batch [300], Loss: 0.1110
# Epoch [ 2/ 7], Batch [400], Loss: 0.1584
# Epoch [ 2/ 7], Batch [500], Loss: 0.1368
# Epoch [ 2/ 7], Batch [600], Loss: 0.1017
# Epoch [ 2/ 7], Batch [700], Loss: 0.1435
# Epoch [ 2/ 7], Batch [800], Loss: 0.0867
# Epoch [ 2/ 7], Batch [900], Loss: 0.1315
# Epoch [ 2/ 7], Batch [1000], Loss: 0.1159
# Epoch [ 2/ 7], Batch [1100], Loss: 0.0897
# Epoch [ 2/ 7], Batch [1200], Loss: 0.0861
# Epoch [ 2/ 7], Batch [1300], Loss: 0.1168
# Epoch [ 2/ 7], Batch [1400], Loss: 0.1462
# Epoch [ 2/ 7], Batch [1500], Loss: 0.2402
# Epoch [ 2/ 7], Batch [1600], Loss: 0.1302
# Epoch [ 2/ 7], Batch [1700], Loss: 0.2155
# Epoch [ 2/ 7], Batch [1800], Loss: 0.1348
# Epoch [ 2/ 7] Loss: 0.1396
# Epoch [ 3/ 7], Batch [100], Loss: 0.0895
# Epoch [ 3/ 7], Batch [200], Loss: 0.1273
# Epoch [ 3/ 7], Batch [300], Loss: 0.0722
# Epoch [ 3/ 7], Batch [400], Loss: 0.0910
# Epoch [ 3/ 7], Batch [500], Loss: 0.1921
# Epoch [ 3/ 7], Batch [600], Loss: 0.1277
# Epoch [ 3/ 7], Batch [700], Loss: 0.1247
# Epoch [ 3/ 7], Batch [800], Loss: 0.2163
# Epoch [ 3/ 7], Batch [900], Loss: 0.1617
# Epoch [ 3/ 7], Batch [1000], Loss: 0.1091
# Epoch [ 3/ 7], Batch [1100], Loss: 0.1446
# Epoch [ 3/ 7], Batch [1200], Loss: 0.0907
# Epoch [ 3/ 7], Batch [1300], Loss: 0.0986
# Epoch [ 3/ 7], Batch [1400], Loss: 0.0712
# Epoch [ 3/ 7], Batch [1500], Loss: 0.1225
# Epoch [ 3/ 7], Batch [1600], Loss: 0.1357
# Epoch [ 3/ 7], Batch [1700], Loss: 0.0942
# Epoch [ 3/ 7], Batch [1800], Loss: 0.0898
# Epoch [ 3/ 7] Loss: 0.1283
# Epoch [ 4/ 7], Batch [100], Loss: 0.2853
# Epoch [ 4/ 7], Batch [200], Loss: 0.1401
# Epoch [ 4/ 7], Batch [300], Loss: 0.2161
# Epoch [ 4/ 7], Batch [400], Loss: 0.1272
# Epoch [ 4/ 7], Batch [500], Loss: 0.1376
# Epoch [ 4/ 7], Batch [600], Loss: 0.1732
# Epoch [ 4/ 7], Batch [700], Loss: 0.1041
# Epoch [ 4/ 7], Batch [800], Loss: 0.2406
# Epoch [ 4/ 7], Batch [900], Loss: 0.1075
# Epoch [ 4/ 7], Batch [1000], Loss: 0.0693
# Epoch [ 4/ 7], Batch [1100], Loss: 0.1006
# Epoch [ 4/ 7], Batch [1200], Loss: 0.1094
# Epoch [ 4/ 7], Batch [1300], Loss: 0.0605
# Epoch [ 4/ 7], Batch [1400], Loss: 0.1651
# Epoch [ 4/ 7], Batch [1500], Loss: 0.0937
# Epoch [ 4/ 7], Batch [1600], Loss: 0.1395
# Epoch [ 4/ 7], Batch [1700], Loss: 0.1820
# Epoch [ 4/ 7], Batch [1800], Loss: 0.0770
# Epoch [ 4/ 7] Loss: 0.1197
# Epoch [ 5/ 7], Batch [100], Loss: 0.1228
# Epoch [ 5/ 7], Batch [200], Loss: 0.1047
# Epoch [ 5/ 7], Batch [300], Loss: 0.1683
# Epoch [ 5/ 7], Batch [400], Loss: 0.0835
# Epoch [ 5/ 7], Batch [500], Loss: 0.0713
# Epoch [ 5/ 7], Batch [600], Loss: 0.0888
# Epoch [ 5/ 7], Batch [700], Loss: 0.1362
# Epoch [ 5/ 7], Batch [800], Loss: 0.2678
# Epoch [ 5/ 7], Batch [900], Loss: 0.1052
# Epoch [ 5/ 7], Batch [1000], Loss: 0.1168
# Epoch [ 5/ 7], Batch [1100], Loss: 0.0960
# Epoch [ 5/ 7], Batch [1200], Loss: 0.0738
# Epoch [ 5/ 7], Batch [1300], Loss: 0.0875
# Epoch [ 5/ 7], Batch [1400], Loss: 0.1287
# Epoch [ 5/ 7], Batch [1500], Loss: 0.0632
# Epoch [ 5/ 7], Batch [1600], Loss: 0.0717
# Epoch [ 5/ 7], Batch [1700], Loss: 0.0900
# Epoch [ 5/ 7], Batch [1800], Loss: 0.1179
# Epoch [ 5/ 7] Loss: 0.1132
# Epoch [ 6/ 7], Batch [100], Loss: 0.1623
# Epoch [ 6/ 7], Batch [200], Loss: 0.1069
# Epoch [ 6/ 7], Batch [300], Loss: 0.1147
# Epoch [ 6/ 7], Batch [400], Loss: 0.0967
# Epoch [ 6/ 7], Batch [500], Loss: 0.1550
# Epoch [ 6/ 7], Batch [600], Loss: 0.2274
# Epoch [ 6/ 7], Batch [700], Loss: 0.0693
# Epoch [ 6/ 7], Batch [800], Loss: 0.0827
# Epoch [ 6/ 7], Batch [900], Loss: 0.0580
# Epoch [ 6/ 7], Batch [1000], Loss: 0.0696
# Epoch [ 6/ 7], Batch [1100], Loss: 0.0788
# Epoch [ 6/ 7], Batch [1200], Loss: 0.0957
# Epoch [ 6/ 7], Batch [1300], Loss: 0.0538
# Epoch [ 6/ 7], Batch [1400], Loss: 0.1563
# Epoch [ 6/ 7], Batch [1500], Loss: 0.1654
# Epoch [ 6/ 7], Batch [1600], Loss: 0.0592
# Epoch [ 6/ 7], Batch [1700], Loss: 0.1821
# Epoch [ 6/ 7], Batch [1800], Loss: 0.0300
# Epoch [ 6/ 7] Loss: 0.1079
# Epoch [ 7/ 7], Batch [100], Loss: 0.1767
# Epoch [ 7/ 7], Batch [200], Loss: 0.1225
# Epoch [ 7/ 7], Batch [300], Loss: 0.0799
# Epoch [ 7/ 7], Batch [400], Loss: 0.0768
# Epoch [ 7/ 7], Batch [500], Loss: 0.0917
# Epoch [ 7/ 7], Batch [600], Loss: 0.1021
# Epoch [ 7/ 7], Batch [700], Loss: 0.0874
# Epoch [ 7/ 7], Batch [800], Loss: 0.1351
# Epoch [ 7/ 7], Batch [900], Loss: 0.0921
# Epoch [ 7/ 7], Batch [1000], Loss: 0.1046
# Epoch [ 7/ 7], Batch [1100], Loss: 0.1132
# Epoch [ 7/ 7], Batch [1200], Loss: 0.0700
# Epoch [ 7/ 7], Batch [1300], Loss: 0.1047
# Epoch [ 7/ 7], Batch [1400], Loss: 0.0637
# Epoch [ 7/ 7], Batch [1500], Loss: 0.1056
# Epoch [ 7/ 7], Batch [1600], Loss: 0.1880
# Epoch [ 7/ 7], Batch [1700], Loss: 0.1041
# Epoch [ 7/ 7], Batch [1800], Loss: 0.0659
# Epoch [ 7/ 7] Loss: 0.1041
# F1-scores: train = 0.6573 ; test = 0.6187
#
# Fold [2/4]: --------------------
# Epoch [ 1/ 7], Batch [100], Loss: 0.1734
# Epoch [ 1/ 7], Batch [200], Loss: 0.2215
# Epoch [ 1/ 7], Batch [300], Loss: 0.1427
# Epoch [ 1/ 7], Batch [400], Loss: 0.1965
# Epoch [ 1/ 7], Batch [500], Loss: 0.2702
# Epoch [ 1/ 7], Batch [600], Loss: 0.0918
# Epoch [ 1/ 7], Batch [700], Loss: 0.1084
# Epoch [ 1/ 7], Batch [800], Loss: 0.2128
# Epoch [ 1/ 7], Batch [900], Loss: 0.1793
# Epoch [ 1/ 7], Batch [1000], Loss: 0.1361
# Epoch [ 1/ 7], Batch [1100], Loss: 0.1169
# Epoch [ 1/ 7], Batch [1200], Loss: 0.0800
# Epoch [ 1/ 7], Batch [1300], Loss: 0.1338
# Epoch [ 1/ 7], Batch [1400], Loss: 0.1470
# Epoch [ 1/ 7], Batch [1500], Loss: 0.1419
# Epoch [ 1/ 7], Batch [1600], Loss: 0.1682
# Epoch [ 1/ 7], Batch [1700], Loss: 0.2203
# Epoch [ 1/ 7], Batch [1800], Loss: 0.2974
# Epoch [ 1/ 7] Loss: 0.1638
# Epoch [ 2/ 7], Batch [100], Loss: 0.1399
# Epoch [ 2/ 7], Batch [200], Loss: 0.2544
# Epoch [ 2/ 7], Batch [300], Loss: 0.1269
# Epoch [ 2/ 7], Batch [400], Loss: 0.0920
# Epoch [ 2/ 7], Batch [500], Loss: 0.1334
# Epoch [ 2/ 7], Batch [600], Loss: 0.0648
# Epoch [ 2/ 7], Batch [700], Loss: 0.1653
# Epoch [ 2/ 7], Batch [800], Loss: 0.1289
# Epoch [ 2/ 7], Batch [900], Loss: 0.2523
# Epoch [ 2/ 7], Batch [1000], Loss: 0.1162
# Epoch [ 2/ 7], Batch [1100], Loss: 0.1025
# Epoch [ 2/ 7], Batch [1200], Loss: 0.1152
# Epoch [ 2/ 7], Batch [1300], Loss: 0.1613
# Epoch [ 2/ 7], Batch [1400], Loss: 0.0713
# Epoch [ 2/ 7], Batch [1500], Loss: 0.0989
# Epoch [ 2/ 7], Batch [1600], Loss: 0.1387
# Epoch [ 2/ 7], Batch [1700], Loss: 0.1513
# Epoch [ 2/ 7], Batch [1800], Loss: 0.2274
# Epoch [ 2/ 7] Loss: 0.1375
# Epoch [ 3/ 7], Batch [100], Loss: 0.0927
# Epoch [ 3/ 7], Batch [200], Loss: 0.1987
# Epoch [ 3/ 7], Batch [300], Loss: 0.0728
# Epoch [ 3/ 7], Batch [400], Loss: 0.0952
# Epoch [ 3/ 7], Batch [500], Loss: 0.2583
# Epoch [ 3/ 7], Batch [600], Loss: 0.1411
# Epoch [ 3/ 7], Batch [700], Loss: 0.0808
# Epoch [ 3/ 7], Batch [800], Loss: 0.0995
# Epoch [ 3/ 7], Batch [900], Loss: 0.2796
# Epoch [ 3/ 7], Batch [1000], Loss: 0.0697
# Epoch [ 3/ 7], Batch [1100], Loss: 0.0803
# Epoch [ 3/ 7], Batch [1200], Loss: 0.0998
# Epoch [ 3/ 7], Batch [1300], Loss: 0.0906
# Epoch [ 3/ 7], Batch [1400], Loss: 0.1970
# Epoch [ 3/ 7], Batch [1500], Loss: 0.1888
# Epoch [ 3/ 7], Batch [1600], Loss: 0.1145
# Epoch [ 3/ 7], Batch [1700], Loss: 0.0594
# Epoch [ 3/ 7], Batch [1800], Loss: 0.0758
# Epoch [ 3/ 7] Loss: 0.1270
# Epoch [ 4/ 7], Batch [100], Loss: 0.1799
# Epoch [ 4/ 7], Batch [200], Loss: 0.1163
# Epoch [ 4/ 7], Batch [300], Loss: 0.0918
# Epoch [ 4/ 7], Batch [400], Loss: 0.0837
# Epoch [ 4/ 7], Batch [500], Loss: 0.1058
# Epoch [ 4/ 7], Batch [600], Loss: 0.1238
# Epoch [ 4/ 7], Batch [700], Loss: 0.1390
# Epoch [ 4/ 7], Batch [800], Loss: 0.0601
# Epoch [ 4/ 7], Batch [900], Loss: 0.0994
# Epoch [ 4/ 7], Batch [1000], Loss: 0.0638
# Epoch [ 4/ 7], Batch [1100], Loss: 0.0676
# Epoch [ 4/ 7], Batch [1200], Loss: 0.1137
# Epoch [ 4/ 7], Batch [1300], Loss: 0.1026
# Epoch [ 4/ 7], Batch [1400], Loss: 0.0806
# Epoch [ 4/ 7], Batch [1500], Loss: 0.0979
# Epoch [ 4/ 7], Batch [1600], Loss: 0.1199
# Epoch [ 4/ 7], Batch [1700], Loss: 0.0644
# Epoch [ 4/ 7], Batch [1800], Loss: 0.0867
# Epoch [ 4/ 7] Loss: 0.1201
# Epoch [ 5/ 7], Batch [100], Loss: 0.1414
# Epoch [ 5/ 7], Batch [200], Loss: 0.0497
# Epoch [ 5/ 7], Batch [300], Loss: 0.0872
# Epoch [ 5/ 7], Batch [400], Loss: 0.2387
# Epoch [ 5/ 7], Batch [500], Loss: 0.0756
# Epoch [ 5/ 7], Batch [600], Loss: 0.0695
# Epoch [ 5/ 7], Batch [700], Loss: 0.1066
# Epoch [ 5/ 7], Batch [800], Loss: 0.2024
# Epoch [ 5/ 7], Batch [900], Loss: 0.1670
# Epoch [ 5/ 7], Batch [1000], Loss: 0.1364
# Epoch [ 5/ 7], Batch [1100], Loss: 0.1429
# Epoch [ 5/ 7], Batch [1200], Loss: 0.2207
# Epoch [ 5/ 7], Batch [1300], Loss: 0.0853
# Epoch [ 5/ 7], Batch [1400], Loss: 0.0700
# Epoch [ 5/ 7], Batch [1500], Loss: 0.1071
# Epoch [ 5/ 7], Batch [1600], Loss: 0.2428
# Epoch [ 5/ 7], Batch [1700], Loss: 0.1707
# Epoch [ 5/ 7], Batch [1800], Loss: 0.1465
# Epoch [ 5/ 7] Loss: 0.1148
# Epoch [ 6/ 7], Batch [100], Loss: 0.1286
# Epoch [ 6/ 7], Batch [200], Loss: 0.0945
# Epoch [ 6/ 7], Batch [300], Loss: 0.0524
# Epoch [ 6/ 7], Batch [400], Loss: 0.1162
# Epoch [ 6/ 7], Batch [500], Loss: 0.0981
# Epoch [ 6/ 7], Batch [600], Loss: 0.0917
# Epoch [ 6/ 7], Batch [700], Loss: 0.0578
# Epoch [ 6/ 7], Batch [800], Loss: 0.1204
# Epoch [ 6/ 7], Batch [900], Loss: 0.1499
# Epoch [ 6/ 7], Batch [1000], Loss: 0.1304
# Epoch [ 6/ 7], Batch [1100], Loss: 0.0697
# Epoch [ 6/ 7], Batch [1200], Loss: 0.1084
# Epoch [ 6/ 7], Batch [1300], Loss: 0.1293
# Epoch [ 6/ 7], Batch [1400], Loss: 0.0861
# Epoch [ 6/ 7], Batch [1500], Loss: 0.1324
# Epoch [ 6/ 7], Batch [1600], Loss: 0.1009
# Epoch [ 6/ 7], Batch [1700], Loss: 0.0848
# Epoch [ 6/ 7], Batch [1800], Loss: 0.1339
# Epoch [ 6/ 7] Loss: 0.1092
# Epoch [ 7/ 7], Batch [100], Loss: 0.0456
# Epoch [ 7/ 7], Batch [200], Loss: 0.1691
# Epoch [ 7/ 7], Batch [300], Loss: 0.1455
# Epoch [ 7/ 7], Batch [400], Loss: 0.0721
# Epoch [ 7/ 7], Batch [500], Loss: 0.0378
# Epoch [ 7/ 7], Batch [600], Loss: 0.1546
# Epoch [ 7/ 7], Batch [700], Loss: 0.0796
# Epoch [ 7/ 7], Batch [800], Loss: 0.0772
# Epoch [ 7/ 7], Batch [900], Loss: 0.0716
# Epoch [ 7/ 7], Batch [1000], Loss: 0.1287
# Epoch [ 7/ 7], Batch [1100], Loss: 0.1188
# Epoch [ 7/ 7], Batch [1200], Loss: 0.0700
# Epoch [ 7/ 7], Batch [1300], Loss: 0.0895
# Epoch [ 7/ 7], Batch [1400], Loss: 0.1381
# Epoch [ 7/ 7], Batch [1500], Loss: 0.1155
# Epoch [ 7/ 7], Batch [1600], Loss: 0.1082
# Epoch [ 7/ 7], Batch [1700], Loss: 0.1454
# Epoch [ 7/ 7], Batch [1800], Loss: 0.1408
# Epoch [ 7/ 7] Loss: 0.1039
# F1-scores: train = 0.7896 ; test = 0.7561
#
# Fold [3/4]: --------------------
# Epoch [ 1/ 7], Batch [100], Loss: 0.1961
# Epoch [ 1/ 7], Batch [200], Loss: 0.1514
# Epoch [ 1/ 7], Batch [300], Loss: 0.1685
# Epoch [ 1/ 7], Batch [400], Loss: 0.1291
# Epoch [ 1/ 7], Batch [500], Loss: 0.1749
# Epoch [ 1/ 7], Batch [600], Loss: 0.1167
# Epoch [ 1/ 7], Batch [700], Loss: 0.1362
# Epoch [ 1/ 7], Batch [800], Loss: 0.0978
# Epoch [ 1/ 7], Batch [900], Loss: 0.1158
# Epoch [ 1/ 7], Batch [1000], Loss: 0.1966
# Epoch [ 1/ 7], Batch [1100], Loss: 0.1121
# Epoch [ 1/ 7], Batch [1200], Loss: 0.1191
# Epoch [ 1/ 7], Batch [1300], Loss: 0.1087
# Epoch [ 1/ 7], Batch [1400], Loss: 0.1525
# Epoch [ 1/ 7], Batch [1500], Loss: 0.1860
# Epoch [ 1/ 7], Batch [1600], Loss: 0.1794
# Epoch [ 1/ 7], Batch [1700], Loss: 0.1047
# Epoch [ 1/ 7], Batch [1800], Loss: 0.0842
# Epoch [ 1/ 7] Loss: 0.1573
# Epoch [ 2/ 7], Batch [100], Loss: 0.1033
# Epoch [ 2/ 7], Batch [200], Loss: 0.1336
# Epoch [ 2/ 7], Batch [300], Loss: 0.1019
# Epoch [ 2/ 7], Batch [400], Loss: 0.2235
# Epoch [ 2/ 7], Batch [500], Loss: 0.0931
# Epoch [ 2/ 7], Batch [600], Loss: 0.1030
# Epoch [ 2/ 7], Batch [700], Loss: 0.2293
# Epoch [ 2/ 7], Batch [800], Loss: 0.1093
# Epoch [ 2/ 7], Batch [900], Loss: 0.1199
# Epoch [ 2/ 7], Batch [1000], Loss: 0.1382
# Epoch [ 2/ 7], Batch [1100], Loss: 0.1561
# Epoch [ 2/ 7], Batch [1200], Loss: 0.1066
# Epoch [ 2/ 7], Batch [1300], Loss: 0.1443
# Epoch [ 2/ 7], Batch [1400], Loss: 0.1036
# Epoch [ 2/ 7], Batch [1500], Loss: 0.1473
# Epoch [ 2/ 7], Batch [1600], Loss: 0.2177
# Epoch [ 2/ 7], Batch [1700], Loss: 0.1571
# Epoch [ 2/ 7], Batch [1800], Loss: 0.0739
# Epoch [ 2/ 7] Loss: 0.1345
# Epoch [ 3/ 7], Batch [100], Loss: 0.1305
# Epoch [ 3/ 7], Batch [200], Loss: 0.0736
# Epoch [ 3/ 7], Batch [300], Loss: 0.0868
# Epoch [ 3/ 7], Batch [400], Loss: 0.0725
# Epoch [ 3/ 7], Batch [500], Loss: 0.1939
# Epoch [ 3/ 7], Batch [600], Loss: 0.1355
# Epoch [ 3/ 7], Batch [700], Loss: 0.0851
# Epoch [ 3/ 7], Batch [800], Loss: 0.0585
# Epoch [ 3/ 7], Batch [900], Loss: 0.1248
# Epoch [ 3/ 7], Batch [1000], Loss: 0.1031
# Epoch [ 3/ 7], Batch [1100], Loss: 0.0678
# Epoch [ 3/ 7], Batch [1200], Loss: 0.1099
# Epoch [ 3/ 7], Batch [1300], Loss: 0.2464
# Epoch [ 3/ 7], Batch [1400], Loss: 0.1896
# Epoch [ 3/ 7], Batch [1500], Loss: 0.1120
# Epoch [ 3/ 7], Batch [1600], Loss: 0.0898
# Epoch [ 3/ 7], Batch [1700], Loss: 0.1207
# Epoch [ 3/ 7], Batch [1800], Loss: 0.3174
# Epoch [ 3/ 7] Loss: 0.1247
# Epoch [ 4/ 7], Batch [100], Loss: 0.1328
# Epoch [ 4/ 7], Batch [200], Loss: 0.2128
# Epoch [ 4/ 7], Batch [300], Loss: 0.1874
# Epoch [ 4/ 7], Batch [400], Loss: 0.1024
# Epoch [ 4/ 7], Batch [500], Loss: 0.2517
# Epoch [ 4/ 7], Batch [600], Loss: 0.0721
# Epoch [ 4/ 7], Batch [700], Loss: 0.0308
# Epoch [ 4/ 7], Batch [800], Loss: 0.0561
# Epoch [ 4/ 7], Batch [900], Loss: 0.2491
# Epoch [ 4/ 7], Batch [1000], Loss: 0.0924
# Epoch [ 4/ 7], Batch [1100], Loss: 0.1001
# Epoch [ 4/ 7], Batch [1200], Loss: 0.2229
# Epoch [ 4/ 7], Batch [1300], Loss: 0.4066
# Epoch [ 4/ 7], Batch [1400], Loss: 0.0734
# Epoch [ 4/ 7], Batch [1500], Loss: 0.1334
# Epoch [ 4/ 7], Batch [1600], Loss: 0.1199
# Epoch [ 4/ 7], Batch [1700], Loss: 0.1476
# Epoch [ 4/ 7], Batch [1800], Loss: 0.0569
# Epoch [ 4/ 7] Loss: 0.1168
# Epoch [ 5/ 7], Batch [100], Loss: 0.0713
# Epoch [ 5/ 7], Batch [200], Loss: 0.0632
# Epoch [ 5/ 7], Batch [300], Loss: 0.0531
# Epoch [ 5/ 7], Batch [400], Loss: 0.1538
# Epoch [ 5/ 7], Batch [500], Loss: 0.1021
# Epoch [ 5/ 7], Batch [600], Loss: 0.1077
# Epoch [ 5/ 7], Batch [700], Loss: 0.1191
# Epoch [ 5/ 7], Batch [800], Loss: 0.0973
# Epoch [ 5/ 7], Batch [900], Loss: 0.1550
# Epoch [ 5/ 7], Batch [1000], Loss: 0.1987
# Epoch [ 5/ 7], Batch [1100], Loss: 0.1010
# Epoch [ 5/ 7], Batch [1200], Loss: 0.1138
# Epoch [ 5/ 7], Batch [1300], Loss: 0.0696
# Epoch [ 5/ 7], Batch [1400], Loss: 0.1793
# Epoch [ 5/ 7], Batch [1500], Loss: 0.0707
# Epoch [ 5/ 7], Batch [1600], Loss: 0.1182
# Epoch [ 5/ 7], Batch [1700], Loss: 0.0634
# Epoch [ 5/ 7], Batch [1800], Loss: 0.2149
# Epoch [ 5/ 7] Loss: 0.1098
# Epoch [ 6/ 7], Batch [100], Loss: 0.0295
# Epoch [ 6/ 7], Batch [200], Loss: 0.1083
# Epoch [ 6/ 7], Batch [300], Loss: 0.0999
# Epoch [ 6/ 7], Batch [400], Loss: 0.1105
# Epoch [ 6/ 7], Batch [500], Loss: 0.0774
# Epoch [ 6/ 7], Batch [600], Loss: 0.1051
# Epoch [ 6/ 7], Batch [700], Loss: 0.1259
# Epoch [ 6/ 7], Batch [800], Loss: 0.0715
# Epoch [ 6/ 7], Batch [900], Loss: 0.1240
# Epoch [ 6/ 7], Batch [1000], Loss: 0.1010
# Epoch [ 6/ 7], Batch [1100], Loss: 0.0517
# Epoch [ 6/ 7], Batch [1200], Loss: 0.0908
# Epoch [ 6/ 7], Batch [1300], Loss: 0.0751
# Epoch [ 6/ 7], Batch [1400], Loss: 0.0500
# Epoch [ 6/ 7], Batch [1500], Loss: 0.1017
# Epoch [ 6/ 7], Batch [1600], Loss: 0.0569
# Epoch [ 6/ 7], Batch [1700], Loss: 0.1027
# Epoch [ 6/ 7], Batch [1800], Loss: 0.4088
# Epoch [ 6/ 7] Loss: 0.1044
# Epoch [ 7/ 7], Batch [100], Loss: 0.0666
# Epoch [ 7/ 7], Batch [200], Loss: 0.0699
# Epoch [ 7/ 7], Batch [300], Loss: 0.1072
# Epoch [ 7/ 7], Batch [400], Loss: 0.0752
# Epoch [ 7/ 7], Batch [500], Loss: 0.1037
# Epoch [ 7/ 7], Batch [600], Loss: 0.0498
# Epoch [ 7/ 7], Batch [700], Loss: 0.2406
# Epoch [ 7/ 7], Batch [800], Loss: 0.0984
# Epoch [ 7/ 7], Batch [900], Loss: 0.0973
# Epoch [ 7/ 7], Batch [1000], Loss: 0.1057
# Epoch [ 7/ 7], Batch [1100], Loss: 0.1820
# Epoch [ 7/ 7], Batch [1200], Loss: 0.0622
# Epoch [ 7/ 7], Batch [1300], Loss: 0.0766
# Epoch [ 7/ 7], Batch [1400], Loss: 0.0992
# Epoch [ 7/ 7], Batch [1500], Loss: 0.1409
# Epoch [ 7/ 7], Batch [1600], Loss: 0.0674
# Epoch [ 7/ 7], Batch [1700], Loss: 0.2114
# Epoch [ 7/ 7], Batch [1800], Loss: 0.0616
# Epoch [ 7/ 7] Loss: 0.1001
# F1-scores: train = 0.7655 ; test = 0.7151
#
# Fold [4/4]: --------------------
# Epoch [ 1/ 7], Batch [100], Loss: 0.2089
# Epoch [ 1/ 7], Batch [200], Loss: 0.1540
# Epoch [ 1/ 7], Batch [300], Loss: 0.1830
# Epoch [ 1/ 7], Batch [400], Loss: 0.1693
# Epoch [ 1/ 7], Batch [500], Loss: 0.1140
# Epoch [ 1/ 7], Batch [600], Loss: 0.1357
# Epoch [ 1/ 7], Batch [700], Loss: 0.1375
# Epoch [ 1/ 7], Batch [800], Loss: 0.1970
# Epoch [ 1/ 7], Batch [900], Loss: 0.0976
# Epoch [ 1/ 7], Batch [1000], Loss: 0.2011
# Epoch [ 1/ 7], Batch [1100], Loss: 0.1018
# Epoch [ 1/ 7], Batch [1200], Loss: 0.1869
# Epoch [ 1/ 7], Batch [1300], Loss: 0.0962
# Epoch [ 1/ 7], Batch [1400], Loss: 0.1139
# Epoch [ 1/ 7], Batch [1500], Loss: 0.1097
# Epoch [ 1/ 7], Batch [1600], Loss: 0.2987
# Epoch [ 1/ 7], Batch [1700], Loss: 0.1390
# Epoch [ 1/ 7], Batch [1800], Loss: 0.1076
# Epoch [ 1/ 7] Loss: 0.1621
# Epoch [ 2/ 7], Batch [100], Loss: 0.2185
# Epoch [ 2/ 7], Batch [200], Loss: 0.1781
# Epoch [ 2/ 7], Batch [300], Loss: 0.0956
# Epoch [ 2/ 7], Batch [400], Loss: 0.1139
# Epoch [ 2/ 7], Batch [500], Loss: 0.1616
# Epoch [ 2/ 7], Batch [600], Loss: 0.1235
# Epoch [ 2/ 7], Batch [700], Loss: 0.1072
# Epoch [ 2/ 7], Batch [800], Loss: 0.1694
# Epoch [ 2/ 7], Batch [900], Loss: 0.1779
# Epoch [ 2/ 7], Batch [1000], Loss: 0.1207
# Epoch [ 2/ 7], Batch [1100], Loss: 0.1187
# Epoch [ 2/ 7], Batch [1200], Loss: 0.0930
# Epoch [ 2/ 7], Batch [1300], Loss: 0.1299
# Epoch [ 2/ 7], Batch [1400], Loss: 0.1666
# Epoch [ 2/ 7], Batch [1500], Loss: 0.1922
# Epoch [ 2/ 7], Batch [1600], Loss: 0.1880
# Epoch [ 2/ 7], Batch [1700], Loss: 0.0650
# Epoch [ 2/ 7], Batch [1800], Loss: 0.0806
# Epoch [ 2/ 7] Loss: 0.1389
# Epoch [ 3/ 7], Batch [100], Loss: 0.0881
# Epoch [ 3/ 7], Batch [200], Loss: 0.1399
# Epoch [ 3/ 7], Batch [300], Loss: 0.0989
# Epoch [ 3/ 7], Batch [400], Loss: 0.1252
# Epoch [ 3/ 7], Batch [500], Loss: 0.0773
# Epoch [ 3/ 7], Batch [600], Loss: 0.0843
# Epoch [ 3/ 7], Batch [700], Loss: 0.1253
# Epoch [ 3/ 7], Batch [800], Loss: 0.0926
# Epoch [ 3/ 7], Batch [900], Loss: 0.1059
# Epoch [ 3/ 7], Batch [1000], Loss: 0.1383
# Epoch [ 3/ 7], Batch [1100], Loss: 0.1151
# Epoch [ 3/ 7], Batch [1200], Loss: 0.1304
# Epoch [ 3/ 7], Batch [1300], Loss: 0.1705
# Epoch [ 3/ 7], Batch [1400], Loss: 0.1610
# Epoch [ 3/ 7], Batch [1500], Loss: 0.1304
# Epoch [ 3/ 7], Batch [1600], Loss: 0.0544
# Epoch [ 3/ 7], Batch [1700], Loss: 0.1228
# Epoch [ 3/ 7], Batch [1800], Loss: 0.0724
# Epoch [ 3/ 7] Loss: 0.1293
# Epoch [ 4/ 7], Batch [100], Loss: 0.0886
# Epoch [ 4/ 7], Batch [200], Loss: 0.0432
# Epoch [ 4/ 7], Batch [300], Loss: 0.0667
# Epoch [ 4/ 7], Batch [400], Loss: 0.1132
# Epoch [ 4/ 7], Batch [500], Loss: 0.1036
# Epoch [ 4/ 7], Batch [600], Loss: 0.0579
# Epoch [ 4/ 7], Batch [700], Loss: 0.1746
# Epoch [ 4/ 7], Batch [800], Loss: 0.0715
# Epoch [ 4/ 7], Batch [900], Loss: 0.0900
# Epoch [ 4/ 7], Batch [1000], Loss: 0.0900
# Epoch [ 4/ 7], Batch [1100], Loss: 0.1228
# Epoch [ 4/ 7], Batch [1200], Loss: 0.0739
# Epoch [ 4/ 7], Batch [1300], Loss: 0.1412
# Epoch [ 4/ 7], Batch [1400], Loss: 0.1705
# Epoch [ 4/ 7], Batch [1500], Loss: 0.0830
# Epoch [ 4/ 7], Batch [1600], Loss: 0.1105
# Epoch [ 4/ 7], Batch [1700], Loss: 0.0764
# Epoch [ 4/ 7], Batch [1800], Loss: 0.1049
# Epoch [ 4/ 7] Loss: 0.1209
# Epoch [ 5/ 7], Batch [100], Loss: 0.0710
# Epoch [ 5/ 7], Batch [200], Loss: 0.1201
# Epoch [ 5/ 7], Batch [300], Loss: 0.0880
# Epoch [ 5/ 7], Batch [400], Loss: 0.1008
# Epoch [ 5/ 7], Batch [500], Loss: 0.0593
# Epoch [ 5/ 7], Batch [600], Loss: 0.1338
# Epoch [ 5/ 7], Batch [700], Loss: 0.1404
# Epoch [ 5/ 7], Batch [800], Loss: 0.0828
# Epoch [ 5/ 7], Batch [900], Loss: 0.1574
# Epoch [ 5/ 7], Batch [1000], Loss: 0.0731
# Epoch [ 5/ 7], Batch [1100], Loss: 0.0838
# Epoch [ 5/ 7], Batch [1200], Loss: 0.1236
# Epoch [ 5/ 7], Batch [1300], Loss: 0.0958
# Epoch [ 5/ 7], Batch [1400], Loss: 0.1709
# Epoch [ 5/ 7], Batch [1500], Loss: 0.0995
# Epoch [ 5/ 7], Batch [1600], Loss: 0.1113
# Epoch [ 5/ 7], Batch [1700], Loss: 0.1027
# Epoch [ 5/ 7], Batch [1800], Loss: 0.1004
# Epoch [ 5/ 7] Loss: 0.1141
# Epoch [ 6/ 7], Batch [100], Loss: 0.0956
# Epoch [ 6/ 7], Batch [200], Loss: 0.1523
# Epoch [ 6/ 7], Batch [300], Loss: 0.1009
# Epoch [ 6/ 7], Batch [400], Loss: 0.0939
# Epoch [ 6/ 7], Batch [500], Loss: 0.1038
# Epoch [ 6/ 7], Batch [600], Loss: 0.1059
# Epoch [ 6/ 7], Batch [700], Loss: 0.0897
# Epoch [ 6/ 7], Batch [800], Loss: 0.1291
# Epoch [ 6/ 7], Batch [900], Loss: 0.0942
# Epoch [ 6/ 7], Batch [1000], Loss: 0.0795
# Epoch [ 6/ 7], Batch [1100], Loss: 0.0575
# Epoch [ 6/ 7], Batch [1200], Loss: 0.1022
# Epoch [ 6/ 7], Batch [1300], Loss: 0.1075
# Epoch [ 6/ 7], Batch [1400], Loss: 0.1010
# Epoch [ 6/ 7], Batch [1500], Loss: 0.1352
# Epoch [ 6/ 7], Batch [1600], Loss: 0.1779
# Epoch [ 6/ 7], Batch [1700], Loss: 0.0921
# Epoch [ 6/ 7], Batch [1800], Loss: 0.2056
# Epoch [ 6/ 7] Loss: 0.1086
# Epoch [ 7/ 7], Batch [100], Loss: 0.0739
# Epoch [ 7/ 7], Batch [200], Loss: 0.2360
# Epoch [ 7/ 7], Batch [300], Loss: 0.0777
# Epoch [ 7/ 7], Batch [400], Loss: 0.1108
# Epoch [ 7/ 7], Batch [500], Loss: 0.1436
# Epoch [ 7/ 7], Batch [600], Loss: 0.0824
# Epoch [ 7/ 7], Batch [700], Loss: 0.0622
# Epoch [ 7/ 7], Batch [800], Loss: 0.1139
# Epoch [ 7/ 7], Batch [900], Loss: 0.0708
# Epoch [ 7/ 7], Batch [1000], Loss: 0.0581
# Epoch [ 7/ 7], Batch [1100], Loss: 0.0712
# Epoch [ 7/ 7], Batch [1200], Loss: 0.0543
# Epoch [ 7/ 7], Batch [1300], Loss: 0.0783
# Epoch [ 7/ 7], Batch [1400], Loss: 0.0603
# Epoch [ 7/ 7], Batch [1500], Loss: 0.0473
# Epoch [ 7/ 7], Batch [1600], Loss: 0.1108
# Epoch [ 7/ 7], Batch [1700], Loss: 0.1251
# Epoch [ 7/ 7], Batch [1800], Loss: 0.0905
# Epoch [ 7/ 7] Loss: 0.1030
# F1-scores: train = 0.4792 ; test = 0.4492
#
# Cross-validation effectuated in 1474.604 seconds
# F1 training: 0.6729 +/- 0.1224
# F1 testing:  0.6348 +/- 0.1182
# (<matplotlib.legend.Legend at 0x7fd7895332e8>,
#  <function matplotlib.pyplot.show>,
#  (0, 1))

# %% [markdown]
# ## 2.5 Grid-search
# Do a grid search by calling the k-fold cross validation for different values of a parameter

# %%
window_sizes = [16, 32, 48, 64]
fold = 4
seed = 3

f1_train = np.zeros((len(window_sizes), fold))
f1_test = np.zeros((len(window_sizes), fold))

start = time.time()
np.random.seed(seed)
torch.manual_seed(seed)
for i in range(len(window_sizes)):
    print("\n\nSearch [%d/%d]: " % (i+1, len(window_sizes)) + "*" * 20)
    f1_train[i,:], f1_test[i,:] = cross_validation(
        x_train=x_train,
        y_train=y_train,
        window_size=window_sizes[i],
        learning_rate=1e-3,
        num_epoch=5,
        batch_size=25,
        num_fold=fold,
        seed=None,
        verbose=True
    )
end = time.time()
print("\nGrid-search effectuated in %.3f seconds" % (end-start))

plt.figure()
plt.errorbar(window_sizes, f1_train.mean(axis=1), f1_train.std(axis=1))
plt.errorbar(window_sizes, f1_test.mean(axis=1), f1_test.std(axis=1))
plt.legend(["Train", "Test"]), plt.grid("on")
plt.ylabel("F1-Score"), plt.ylim([0, 1])
plt.xlabel("Window size [pixel]")
plt.show()
# Out:
#  Search [1/4]: ********************
#
# Fold [1/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2015
# Epoch [ 1/ 5], Batch [200], Loss: 0.1926
# Epoch [ 1/ 5], Batch [300], Loss: 0.3225
# Epoch [ 1/ 5], Batch [400], Loss: 0.2302
# Epoch [ 1/ 5], Batch [500], Loss: 0.2429
# Epoch [ 1/ 5], Batch [600], Loss: 0.1334
# Epoch [ 1/ 5], Batch [700], Loss: 0.1871
# Epoch [ 1/ 5], Batch [800], Loss: 0.2101
# Epoch [ 1/ 5], Batch [900], Loss: 0.1595
# Epoch [ 1/ 5], Batch [1000], Loss: 0.2417
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1456
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1833
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1621
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1263
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1804
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1711
# Epoch [ 1/ 5], Batch [1700], Loss: 0.3286
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2048
# Epoch [ 2/ 5], Batch [100], Loss: 0.2283
# Epoch [ 2/ 5], Batch [200], Loss: 0.2217
# Epoch [ 2/ 5], Batch [300], Loss: 0.2364
# Epoch [ 2/ 5], Batch [400], Loss: 0.1054
# Epoch [ 2/ 5], Batch [500], Loss: 0.1413
# Epoch [ 2/ 5], Batch [600], Loss: 0.1232
# Epoch [ 2/ 5], Batch [700], Loss: 0.1806
# Epoch [ 2/ 5], Batch [800], Loss: 0.1365
# Epoch [ 2/ 5], Batch [900], Loss: 0.2577
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1151
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1399
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1386
# Epoch [ 2/ 5], Batch [1300], Loss: 0.2481
# Epoch [ 2/ 5], Batch [1400], Loss: 0.2660
# Epoch [ 2/ 5], Batch [1500], Loss: 0.2701
# Epoch [ 2/ 5], Batch [1600], Loss: 0.3086
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1199
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1410
# Epoch [ 3/ 5], Batch [100], Loss: 0.2210
# Epoch [ 3/ 5], Batch [200], Loss: 0.2184
# Epoch [ 3/ 5], Batch [300], Loss: 0.2089
# Epoch [ 3/ 5], Batch [400], Loss: 0.3006
# Epoch [ 3/ 5], Batch [500], Loss: 0.2564
# Epoch [ 3/ 5], Batch [600], Loss: 0.2192
# Epoch [ 3/ 5], Batch [700], Loss: 0.1367
# Epoch [ 3/ 5], Batch [800], Loss: 0.0653
# Epoch [ 3/ 5], Batch [900], Loss: 0.2002
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1811
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1036
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1575
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1133
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1223
# Epoch [ 3/ 5], Batch [1500], Loss: 0.2730
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1411
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1749
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1875
# Epoch [ 4/ 5], Batch [100], Loss: 0.2050
# Epoch [ 4/ 5], Batch [200], Loss: 0.1900
# Epoch [ 4/ 5], Batch [300], Loss: 0.1465
# Epoch [ 4/ 5], Batch [400], Loss: 0.1367
# Epoch [ 4/ 5], Batch [500], Loss: 0.1985
# Epoch [ 4/ 5], Batch [600], Loss: 0.1439
# Epoch [ 4/ 5], Batch [700], Loss: 0.1071
# Epoch [ 4/ 5], Batch [800], Loss: 0.2438
# Epoch [ 4/ 5], Batch [900], Loss: 0.2170
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1757
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1775
# Epoch [ 4/ 5], Batch [1200], Loss: 0.2077
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1516
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1641
# Epoch [ 4/ 5], Batch [1500], Loss: 0.2930
# Epoch [ 4/ 5], Batch [1600], Loss: 0.2470
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1369
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1983
# Epoch [ 5/ 5], Batch [100], Loss: 0.1390
# Epoch [ 5/ 5], Batch [200], Loss: 0.2870
# Epoch [ 5/ 5], Batch [300], Loss: 0.2018
# Epoch [ 5/ 5], Batch [400], Loss: 0.2602
# Epoch [ 5/ 5], Batch [500], Loss: 0.2305
# Epoch [ 5/ 5], Batch [600], Loss: 0.1291
# Epoch [ 5/ 5], Batch [700], Loss: 0.2030
# Epoch [ 5/ 5], Batch [800], Loss: 0.1241
# Epoch [ 5/ 5], Batch [900], Loss: 0.2105
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1702
# Epoch [ 5/ 5], Batch [1100], Loss: 0.2389
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1132
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1437
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1854
# Epoch [ 5/ 5], Batch [1500], Loss: 0.2587
# Epoch [ 5/ 5], Batch [1600], Loss: 0.3447
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1141
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1345
# F1-scores: train = 0.0254 ; test = 0.0178
#
# Fold [2/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1583
# Epoch [ 1/ 5], Batch [200], Loss: 0.1970
# Epoch [ 1/ 5], Batch [300], Loss: 0.1694
# Epoch [ 1/ 5], Batch [400], Loss: 0.3450
# Epoch [ 1/ 5], Batch [500], Loss: 0.2757
# Epoch [ 1/ 5], Batch [600], Loss: 0.1224
# Epoch [ 1/ 5], Batch [700], Loss: 0.1290
# Epoch [ 1/ 5], Batch [800], Loss: 0.2138
# Epoch [ 1/ 5], Batch [900], Loss: 0.1952
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1618
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1701
# Epoch [ 1/ 5], Batch [1200], Loss: 0.3091
# Epoch [ 1/ 5], Batch [1300], Loss: 0.2833
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1493
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1213
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1592
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1970
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2641
# Epoch [ 2/ 5], Batch [100], Loss: 0.1990
# Epoch [ 2/ 5], Batch [200], Loss: 0.1510
# Epoch [ 2/ 5], Batch [300], Loss: 0.1304
# Epoch [ 2/ 5], Batch [400], Loss: 0.1058
# Epoch [ 2/ 5], Batch [500], Loss: 0.1517
# Epoch [ 2/ 5], Batch [600], Loss: 0.1776
# Epoch [ 2/ 5], Batch [700], Loss: 0.1197
# Epoch [ 2/ 5], Batch [800], Loss: 0.2765
# Epoch [ 2/ 5], Batch [900], Loss: 0.1814
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1251
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1025
# Epoch [ 2/ 5], Batch [1200], Loss: 0.2277
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1725
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1801
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1558
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1692
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1903
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1008
# Epoch [ 3/ 5], Batch [100], Loss: 0.1569
# Epoch [ 3/ 5], Batch [200], Loss: 0.1912
# Epoch [ 3/ 5], Batch [300], Loss: 0.2006
# Epoch [ 3/ 5], Batch [400], Loss: 0.2574
# Epoch [ 3/ 5], Batch [500], Loss: 0.1490
# Epoch [ 3/ 5], Batch [600], Loss: 0.1924
# Epoch [ 3/ 5], Batch [700], Loss: 0.1715
# Epoch [ 3/ 5], Batch [800], Loss: 0.1800
# Epoch [ 3/ 5], Batch [900], Loss: 0.1238
# Epoch [ 3/ 5], Batch [1000], Loss: 0.2025
# Epoch [ 3/ 5], Batch [1100], Loss: 0.2414
# Epoch [ 3/ 5], Batch [1200], Loss: 0.2395
# Epoch [ 3/ 5], Batch [1300], Loss: 0.2167
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1592
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1764
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1444
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1487
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1623
# Epoch [ 4/ 5], Batch [100], Loss: 0.1820
# Epoch [ 4/ 5], Batch [200], Loss: 0.1410
# Epoch [ 4/ 5], Batch [300], Loss: 0.1755
# Epoch [ 4/ 5], Batch [400], Loss: 0.1410
# Epoch [ 4/ 5], Batch [500], Loss: 0.1787
# Epoch [ 4/ 5], Batch [600], Loss: 0.1485
# Epoch [ 4/ 5], Batch [700], Loss: 0.1068
# Epoch [ 4/ 5], Batch [800], Loss: 0.1692
# Epoch [ 4/ 5], Batch [900], Loss: 0.1535
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1410
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1698
# Epoch [ 4/ 5], Batch [1200], Loss: 0.2345
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1570
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1609
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1562
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1170
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1355
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1197
# Epoch [ 5/ 5], Batch [100], Loss: 0.3571
# Epoch [ 5/ 5], Batch [200], Loss: 0.2089
# Epoch [ 5/ 5], Batch [300], Loss: 0.1299
# Epoch [ 5/ 5], Batch [400], Loss: 0.2240
# Epoch [ 5/ 5], Batch [500], Loss: 0.2420
# Epoch [ 5/ 5], Batch [600], Loss: 0.1800
# Epoch [ 5/ 5], Batch [700], Loss: 0.1071
# Epoch [ 5/ 5], Batch [800], Loss: 0.0978
# Epoch [ 5/ 5], Batch [900], Loss: 0.1859
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1731
# Epoch [ 5/ 5], Batch [1100], Loss: 0.2029
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1637
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1841
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1253
# Epoch [ 5/ 5], Batch [1500], Loss: 0.2727
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1283
# Epoch [ 5/ 5], Batch [1700], Loss: 0.3221
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1314
# F1-scores: train = 0.5411 ; test = 0.5178
#
# Fold [3/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2271
# Epoch [ 1/ 5], Batch [200], Loss: 0.1500
# Epoch [ 1/ 5], Batch [300], Loss: 0.1814
# Epoch [ 1/ 5], Batch [400], Loss: 0.1665
# Epoch [ 1/ 5], Batch [500], Loss: 0.1675
# Epoch [ 1/ 5], Batch [600], Loss: 0.3311
# Epoch [ 1/ 5], Batch [700], Loss: 0.1781
# Epoch [ 1/ 5], Batch [800], Loss: 0.1962
# Epoch [ 1/ 5], Batch [900], Loss: 0.2268
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1422
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2413
# Epoch [ 1/ 5], Batch [1200], Loss: 0.2007
# Epoch [ 1/ 5], Batch [1300], Loss: 0.2317
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1815
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1130
# Epoch [ 1/ 5], Batch [1600], Loss: 0.2053
# Epoch [ 1/ 5], Batch [1700], Loss: 0.2675
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1970
# Epoch [ 2/ 5], Batch [100], Loss: 0.1882
# Epoch [ 2/ 5], Batch [200], Loss: 0.1431
# Epoch [ 2/ 5], Batch [300], Loss: 0.2636
# Epoch [ 2/ 5], Batch [400], Loss: 0.1924
# Epoch [ 2/ 5], Batch [500], Loss: 0.1336
# Epoch [ 2/ 5], Batch [600], Loss: 0.1099
# Epoch [ 2/ 5], Batch [700], Loss: 0.1951
# Epoch [ 2/ 5], Batch [800], Loss: 0.1348
# Epoch [ 2/ 5], Batch [900], Loss: 0.1515
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1973
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1849
# Epoch [ 2/ 5], Batch [1200], Loss: 0.2015
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1459
# Epoch [ 2/ 5], Batch [1400], Loss: 0.2157
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1671
# Epoch [ 2/ 5], Batch [1600], Loss: 0.2554
# Epoch [ 2/ 5], Batch [1700], Loss: 0.0977
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1771
# Epoch [ 3/ 5], Batch [100], Loss: 0.1801
# Epoch [ 3/ 5], Batch [200], Loss: 0.2713
# Epoch [ 3/ 5], Batch [300], Loss: 0.0735
# Epoch [ 3/ 5], Batch [400], Loss: 0.1652
# Epoch [ 3/ 5], Batch [500], Loss: 0.1320
# Epoch [ 3/ 5], Batch [600], Loss: 0.2643
# Epoch [ 3/ 5], Batch [700], Loss: 0.1003
# Epoch [ 3/ 5], Batch [800], Loss: 0.1812
# Epoch [ 3/ 5], Batch [900], Loss: 0.1246
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1697
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1241
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1856
# Epoch [ 3/ 5], Batch [1300], Loss: 0.2642
# Epoch [ 3/ 5], Batch [1400], Loss: 0.2020
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1348
# Epoch [ 3/ 5], Batch [1600], Loss: 0.2786
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1377
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1150
# Epoch [ 4/ 5], Batch [100], Loss: 0.3238
# Epoch [ 4/ 5], Batch [200], Loss: 0.1102
# Epoch [ 4/ 5], Batch [300], Loss: 0.1839
# Epoch [ 4/ 5], Batch [400], Loss: 0.1961
# Epoch [ 4/ 5], Batch [500], Loss: 0.1354
# Epoch [ 4/ 5], Batch [600], Loss: 0.1533
# Epoch [ 4/ 5], Batch [700], Loss: 0.1289
# Epoch [ 4/ 5], Batch [800], Loss: 0.1955
# Epoch [ 4/ 5], Batch [900], Loss: 0.1333
# Epoch [ 4/ 5], Batch [1000], Loss: 0.3879
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1552
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1086
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1360
# Epoch [ 4/ 5], Batch [1400], Loss: 0.2285
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1722
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1290
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1897
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1472
# Epoch [ 5/ 5], Batch [100], Loss: 0.1872
# Epoch [ 5/ 5], Batch [200], Loss: 0.1438
# Epoch [ 5/ 5], Batch [300], Loss: 0.1466
# Epoch [ 5/ 5], Batch [400], Loss: 0.1398
# Epoch [ 5/ 5], Batch [500], Loss: 0.1193
# Epoch [ 5/ 5], Batch [600], Loss: 0.1377
# Epoch [ 5/ 5], Batch [700], Loss: 0.0906
# Epoch [ 5/ 5], Batch [800], Loss: 0.1566
# Epoch [ 5/ 5], Batch [900], Loss: 0.1673
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1137
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1461
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1919
# Epoch [ 5/ 5], Batch [1300], Loss: 0.3378
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1657
# Epoch [ 5/ 5], Batch [1500], Loss: 0.2115
# Epoch [ 5/ 5], Batch [1600], Loss: 0.2154
# Epoch [ 5/ 5], Batch [1700], Loss: 0.2601
# Epoch [ 5/ 5], Batch [1800], Loss: 0.2769
# F1-scores: train = 0.4242 ; test = 0.4134
#
# Fold [4/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1527
# Epoch [ 1/ 5], Batch [200], Loss: 0.2233
# Epoch [ 1/ 5], Batch [300], Loss: 0.1825
# Epoch [ 1/ 5], Batch [400], Loss: 0.1083
# Epoch [ 1/ 5], Batch [500], Loss: 0.1373
# Epoch [ 1/ 5], Batch [600], Loss: 0.3243
# Epoch [ 1/ 5], Batch [700], Loss: 0.2432
# Epoch [ 1/ 5], Batch [800], Loss: 0.1804
# Epoch [ 1/ 5], Batch [900], Loss: 0.3439
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1951
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1440
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1909
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1462
# Epoch [ 1/ 5], Batch [1400], Loss: 0.2050
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1386
# Epoch [ 1/ 5], Batch [1600], Loss: 0.2296
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1391
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2110
# Epoch [ 2/ 5], Batch [100], Loss: 0.1652
# Epoch [ 2/ 5], Batch [200], Loss: 0.1904
# Epoch [ 2/ 5], Batch [300], Loss: 0.1876
# Epoch [ 2/ 5], Batch [400], Loss: 0.1012
# Epoch [ 2/ 5], Batch [500], Loss: 0.1790
# Epoch [ 2/ 5], Batch [600], Loss: 0.1741
# Epoch [ 2/ 5], Batch [700], Loss: 0.1257
# Epoch [ 2/ 5], Batch [800], Loss: 0.2433
# Epoch [ 2/ 5], Batch [900], Loss: 0.1430
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1044
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1791
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1523
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1114
# Epoch [ 2/ 5], Batch [1400], Loss: 0.2236
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1006
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1590
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1733
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1821
# Epoch [ 3/ 5], Batch [100], Loss: 0.1830
# Epoch [ 3/ 5], Batch [200], Loss: 0.2370
# Epoch [ 3/ 5], Batch [300], Loss: 0.2457
# Epoch [ 3/ 5], Batch [400], Loss: 0.1939
# Epoch [ 3/ 5], Batch [500], Loss: 0.2191
# Epoch [ 3/ 5], Batch [600], Loss: 0.1479
# Epoch [ 3/ 5], Batch [700], Loss: 0.1238
# Epoch [ 3/ 5], Batch [800], Loss: 0.1793
# Epoch [ 3/ 5], Batch [900], Loss: 0.2053
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1540
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1603
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1086
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1827
# Epoch [ 3/ 5], Batch [1400], Loss: 0.0886
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1275
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1103
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1272
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1451
# Epoch [ 4/ 5], Batch [100], Loss: 0.1159
# Epoch [ 4/ 5], Batch [200], Loss: 0.3575
# Epoch [ 4/ 5], Batch [300], Loss: 0.1460
# Epoch [ 4/ 5], Batch [400], Loss: 0.1094
# Epoch [ 4/ 5], Batch [500], Loss: 0.2158
# Epoch [ 4/ 5], Batch [600], Loss: 0.3397
# Epoch [ 4/ 5], Batch [700], Loss: 0.1738
# Epoch [ 4/ 5], Batch [800], Loss: 0.2454
# Epoch [ 4/ 5], Batch [900], Loss: 0.1294
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1773
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1897
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1167
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1578
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1209
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1568
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1892
# Epoch [ 4/ 5], Batch [1700], Loss: 0.2067
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1711
# Epoch [ 5/ 5], Batch [100], Loss: 0.0933
# Epoch [ 5/ 5], Batch [200], Loss: 0.1089
# Epoch [ 5/ 5], Batch [300], Loss: 0.1657
# Epoch [ 5/ 5], Batch [400], Loss: 0.1182
# Epoch [ 5/ 5], Batch [500], Loss: 0.1760
# Epoch [ 5/ 5], Batch [600], Loss: 0.1760
# Epoch [ 5/ 5], Batch [700], Loss: 0.2360
# Epoch [ 5/ 5], Batch [800], Loss: 0.2337
# Epoch [ 5/ 5], Batch [900], Loss: 0.2809
# Epoch [ 5/ 5], Batch [1000], Loss: 0.2136
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1741
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1217
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1219
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1782
# Epoch [ 5/ 5], Batch [1500], Loss: 0.2207
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1462
# Epoch [ 5/ 5], Batch [1700], Loss: 0.2494
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1384
# F1-scores: train = 0.4830 ; test = 0.4956
#
#
#  Search [2/4]: ********************
#
# Fold [1/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2170
# Epoch [ 1/ 5], Batch [200], Loss: 0.1592
# Epoch [ 1/ 5], Batch [300], Loss: 0.2067
# Epoch [ 1/ 5], Batch [400], Loss: 0.1537
# Epoch [ 1/ 5], Batch [500], Loss: 0.2263
# Epoch [ 1/ 5], Batch [600], Loss: 0.2776
# Epoch [ 1/ 5], Batch [700], Loss: 0.2126
# Epoch [ 1/ 5], Batch [800], Loss: 0.1316
# Epoch [ 1/ 5], Batch [900], Loss: 0.1960
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1464
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2809
# Epoch [ 1/ 5], Batch [1200], Loss: 0.0934
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1310
# Epoch [ 1/ 5], Batch [1400], Loss: 0.2153
# Epoch [ 1/ 5], Batch [1500], Loss: 0.2500
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1228
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1614
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1819
# Epoch [ 2/ 5], Batch [100], Loss: 0.2923
# Epoch [ 2/ 5], Batch [200], Loss: 0.0987
# Epoch [ 2/ 5], Batch [300], Loss: 0.1365
# Epoch [ 2/ 5], Batch [400], Loss: 0.1101
# Epoch [ 2/ 5], Batch [500], Loss: 0.1344
# Epoch [ 2/ 5], Batch [600], Loss: 0.1210
# Epoch [ 2/ 5], Batch [700], Loss: 0.1388
# Epoch [ 2/ 5], Batch [800], Loss: 0.2380
# Epoch [ 2/ 5], Batch [900], Loss: 0.0897
# Epoch [ 2/ 5], Batch [1000], Loss: 0.2716
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1517
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1759
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1345
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1142
# Epoch [ 2/ 5], Batch [1500], Loss: 0.0781
# Epoch [ 2/ 5], Batch [1600], Loss: 0.2398
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1186
# Epoch [ 2/ 5], Batch [1800], Loss: 0.0816
# Epoch [ 3/ 5], Batch [100], Loss: 0.1468
# Epoch [ 3/ 5], Batch [200], Loss: 0.1066
# Epoch [ 3/ 5], Batch [300], Loss: 0.1025
# Epoch [ 3/ 5], Batch [400], Loss: 0.1493
# Epoch [ 3/ 5], Batch [500], Loss: 0.2131
# Epoch [ 3/ 5], Batch [600], Loss: 0.2392
# Epoch [ 3/ 5], Batch [700], Loss: 0.1555
# Epoch [ 3/ 5], Batch [800], Loss: 0.1355
# Epoch [ 3/ 5], Batch [900], Loss: 0.1621
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1796
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1410
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1359
# Epoch [ 3/ 5], Batch [1300], Loss: 0.2189
# Epoch [ 3/ 5], Batch [1400], Loss: 0.0588
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1563
# Epoch [ 3/ 5], Batch [1600], Loss: 0.0795
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1608
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1576
# Epoch [ 4/ 5], Batch [100], Loss: 0.1359
# Epoch [ 4/ 5], Batch [200], Loss: 0.1549
# Epoch [ 4/ 5], Batch [300], Loss: 0.1047
# Epoch [ 4/ 5], Batch [400], Loss: 0.1533
# Epoch [ 4/ 5], Batch [500], Loss: 0.1504
# Epoch [ 4/ 5], Batch [600], Loss: 0.1142
# Epoch [ 4/ 5], Batch [700], Loss: 0.1666
# Epoch [ 4/ 5], Batch [800], Loss: 0.1120
# Epoch [ 4/ 5], Batch [900], Loss: 0.1367
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1331
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1254
# Epoch [ 4/ 5], Batch [1200], Loss: 0.0740
# Epoch [ 4/ 5], Batch [1300], Loss: 0.0904
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1368
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1759
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1063
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1341
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1688
# Epoch [ 5/ 5], Batch [100], Loss: 0.0887
# Epoch [ 5/ 5], Batch [200], Loss: 0.0777
# Epoch [ 5/ 5], Batch [300], Loss: 0.1264
# Epoch [ 5/ 5], Batch [400], Loss: 0.1458
# Epoch [ 5/ 5], Batch [500], Loss: 0.1123
# Epoch [ 5/ 5], Batch [600], Loss: 0.1415
# Epoch [ 5/ 5], Batch [700], Loss: 0.2433
# Epoch [ 5/ 5], Batch [800], Loss: 0.0521
# Epoch [ 5/ 5], Batch [900], Loss: 0.0887
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1714
# Epoch [ 5/ 5], Batch [1100], Loss: 0.3299
# Epoch [ 5/ 5], Batch [1200], Loss: 0.0642
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1118
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0814
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1204
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1130
# Epoch [ 5/ 5], Batch [1700], Loss: 0.3160
# Epoch [ 5/ 5], Batch [1800], Loss: 0.0980
# F1-scores: train = 0.6572 ; test = 0.6541
#
# Fold [2/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1410
# Epoch [ 1/ 5], Batch [200], Loss: 0.1520
# Epoch [ 1/ 5], Batch [300], Loss: 0.1527
# Epoch [ 1/ 5], Batch [400], Loss: 0.2740
# Epoch [ 1/ 5], Batch [500], Loss: 0.3171
# Epoch [ 1/ 5], Batch [600], Loss: 0.1586
# Epoch [ 1/ 5], Batch [700], Loss: 0.0909
# Epoch [ 1/ 5], Batch [800], Loss: 0.0904
# Epoch [ 1/ 5], Batch [900], Loss: 0.1047
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1377
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2374
# Epoch [ 1/ 5], Batch [1200], Loss: 0.2471
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1554
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1211
# Epoch [ 1/ 5], Batch [1500], Loss: 0.2670
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1552
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1333
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2403
# Epoch [ 2/ 5], Batch [100], Loss: 0.1670
# Epoch [ 2/ 5], Batch [200], Loss: 0.1179
# Epoch [ 2/ 5], Batch [300], Loss: 0.1303
# Epoch [ 2/ 5], Batch [400], Loss: 0.1470
# Epoch [ 2/ 5], Batch [500], Loss: 0.2235
# Epoch [ 2/ 5], Batch [600], Loss: 0.1075
# Epoch [ 2/ 5], Batch [700], Loss: 0.3496
# Epoch [ 2/ 5], Batch [800], Loss: 0.1662
# Epoch [ 2/ 5], Batch [900], Loss: 0.1392
# Epoch [ 2/ 5], Batch [1000], Loss: 0.0837
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1849
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1367
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1909
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1221
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1094
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1466
# Epoch [ 2/ 5], Batch [1700], Loss: 0.2238
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1444
# Epoch [ 3/ 5], Batch [100], Loss: 0.1822
# Epoch [ 3/ 5], Batch [200], Loss: 0.1156
# Epoch [ 3/ 5], Batch [300], Loss: 0.1146
# Epoch [ 3/ 5], Batch [400], Loss: 0.2209
# Epoch [ 3/ 5], Batch [500], Loss: 0.1030
# Epoch [ 3/ 5], Batch [600], Loss: 0.2198
# Epoch [ 3/ 5], Batch [700], Loss: 0.1884
# Epoch [ 3/ 5], Batch [800], Loss: 0.1465
# Epoch [ 3/ 5], Batch [900], Loss: 0.0957
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1537
# Epoch [ 3/ 5], Batch [1100], Loss: 0.0923
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1599
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1840
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1656
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1583
# Epoch [ 3/ 5], Batch [1600], Loss: 0.2964
# Epoch [ 3/ 5], Batch [1700], Loss: 0.0902
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0969
# Epoch [ 4/ 5], Batch [100], Loss: 0.2227
# Epoch [ 4/ 5], Batch [200], Loss: 0.1951
# Epoch [ 4/ 5], Batch [300], Loss: 0.0747
# Epoch [ 4/ 5], Batch [400], Loss: 0.1822
# Epoch [ 4/ 5], Batch [500], Loss: 0.1854
# Epoch [ 4/ 5], Batch [600], Loss: 0.1398
# Epoch [ 4/ 5], Batch [700], Loss: 0.1212
# Epoch [ 4/ 5], Batch [800], Loss: 0.3914
# Epoch [ 4/ 5], Batch [900], Loss: 0.0890
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1256
# Epoch [ 4/ 5], Batch [1100], Loss: 0.2025
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1239
# Epoch [ 4/ 5], Batch [1300], Loss: 0.0933
# Epoch [ 4/ 5], Batch [1400], Loss: 0.0821
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1778
# Epoch [ 4/ 5], Batch [1600], Loss: 0.0830
# Epoch [ 4/ 5], Batch [1700], Loss: 0.0903
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1131
# Epoch [ 5/ 5], Batch [100], Loss: 0.0937
# Epoch [ 5/ 5], Batch [200], Loss: 0.2138
# Epoch [ 5/ 5], Batch [300], Loss: 0.2000
# Epoch [ 5/ 5], Batch [400], Loss: 0.1108
# Epoch [ 5/ 5], Batch [500], Loss: 0.1427
# Epoch [ 5/ 5], Batch [600], Loss: 0.0972
# Epoch [ 5/ 5], Batch [700], Loss: 0.1259
# Epoch [ 5/ 5], Batch [800], Loss: 0.0963
# Epoch [ 5/ 5], Batch [900], Loss: 0.3147
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1081
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1402
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1575
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1192
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1357
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1702
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1781
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1955
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1296
# F1-scores: train = 0.5780 ; test = 0.5545
#
# Fold [3/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1838
# Epoch [ 1/ 5], Batch [200], Loss: 0.1682
# Epoch [ 1/ 5], Batch [300], Loss: 0.3005
# Epoch [ 1/ 5], Batch [400], Loss: 0.2733
# Epoch [ 1/ 5], Batch [500], Loss: 0.1261
# Epoch [ 1/ 5], Batch [600], Loss: 0.2907
# Epoch [ 1/ 5], Batch [700], Loss: 0.0997
# Epoch [ 1/ 5], Batch [800], Loss: 0.2981
# Epoch [ 1/ 5], Batch [900], Loss: 0.1820
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1770
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1015
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1874
# Epoch [ 1/ 5], Batch [1300], Loss: 0.0965
# Epoch [ 1/ 5], Batch [1400], Loss: 0.2068
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1052
# Epoch [ 1/ 5], Batch [1600], Loss: 0.0924
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1666
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1311
# Epoch [ 2/ 5], Batch [100], Loss: 0.1531
# Epoch [ 2/ 5], Batch [200], Loss: 0.1626
# Epoch [ 2/ 5], Batch [300], Loss: 0.2115
# Epoch [ 2/ 5], Batch [400], Loss: 0.2208
# Epoch [ 2/ 5], Batch [500], Loss: 0.1993
# Epoch [ 2/ 5], Batch [600], Loss: 0.1749
# Epoch [ 2/ 5], Batch [700], Loss: 0.1070
# Epoch [ 2/ 5], Batch [800], Loss: 0.1943
# Epoch [ 2/ 5], Batch [900], Loss: 0.1650
# Epoch [ 2/ 5], Batch [1000], Loss: 0.3128
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1922
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1192
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1694
# Epoch [ 2/ 5], Batch [1400], Loss: 0.2061
# Epoch [ 2/ 5], Batch [1500], Loss: 0.2400
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1825
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1323
# Epoch [ 2/ 5], Batch [1800], Loss: 0.2145
# Epoch [ 3/ 5], Batch [100], Loss: 0.1683
# Epoch [ 3/ 5], Batch [200], Loss: 0.0945
# Epoch [ 3/ 5], Batch [300], Loss: 0.3455
# Epoch [ 3/ 5], Batch [400], Loss: 0.1625
# Epoch [ 3/ 5], Batch [500], Loss: 0.1411
# Epoch [ 3/ 5], Batch [600], Loss: 0.1935
# Epoch [ 3/ 5], Batch [700], Loss: 0.1807
# Epoch [ 3/ 5], Batch [800], Loss: 0.2334
# Epoch [ 3/ 5], Batch [900], Loss: 0.1877
# Epoch [ 3/ 5], Batch [1000], Loss: 0.0914
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1215
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1015
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1473
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1721
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1832
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1941
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1795
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1882
# Epoch [ 4/ 5], Batch [100], Loss: 0.1471
# Epoch [ 4/ 5], Batch [200], Loss: 0.1004
# Epoch [ 4/ 5], Batch [300], Loss: 0.1635
# Epoch [ 4/ 5], Batch [400], Loss: 0.1021
# Epoch [ 4/ 5], Batch [500], Loss: 0.1405
# Epoch [ 4/ 5], Batch [600], Loss: 0.1541
# Epoch [ 4/ 5], Batch [700], Loss: 0.1466
# Epoch [ 4/ 5], Batch [800], Loss: 0.1430
# Epoch [ 4/ 5], Batch [900], Loss: 0.1300
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1363
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1313
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1103
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1600
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1404
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1329
# Epoch [ 4/ 5], Batch [1600], Loss: 0.2999
# Epoch [ 4/ 5], Batch [1700], Loss: 0.2282
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1397
# Epoch [ 5/ 5], Batch [100], Loss: 0.1555
# Epoch [ 5/ 5], Batch [200], Loss: 0.1542
# Epoch [ 5/ 5], Batch [300], Loss: 0.1851
# Epoch [ 5/ 5], Batch [400], Loss: 0.1495
# Epoch [ 5/ 5], Batch [500], Loss: 0.0986
# Epoch [ 5/ 5], Batch [600], Loss: 0.2059
# Epoch [ 5/ 5], Batch [700], Loss: 0.2840
# Epoch [ 5/ 5], Batch [800], Loss: 0.2604
# Epoch [ 5/ 5], Batch [900], Loss: 0.1630
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1736
# Epoch [ 5/ 5], Batch [1100], Loss: 0.2348
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1358
# Epoch [ 5/ 5], Batch [1300], Loss: 0.0937
# Epoch [ 5/ 5], Batch [1400], Loss: 0.2006
# Epoch [ 5/ 5], Batch [1500], Loss: 0.0988
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1681
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1513
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1731
# F1-scores: train = 0.5800 ; test = 0.5764
#
# Fold [4/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2040
# Epoch [ 1/ 5], Batch [200], Loss: 0.2300
# Epoch [ 1/ 5], Batch [300], Loss: 0.2201
# Epoch [ 1/ 5], Batch [400], Loss: 0.1814
# Epoch [ 1/ 5], Batch [500], Loss: 0.2026
# Epoch [ 1/ 5], Batch [600], Loss: 0.2258
# Epoch [ 1/ 5], Batch [700], Loss: 0.1550
# Epoch [ 1/ 5], Batch [800], Loss: 0.1838
# Epoch [ 1/ 5], Batch [900], Loss: 0.1174
# Epoch [ 1/ 5], Batch [1000], Loss: 0.3341
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1743
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1590
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1777
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1392
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1168
# Epoch [ 1/ 5], Batch [1600], Loss: 0.2044
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1432
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1530
# Epoch [ 2/ 5], Batch [100], Loss: 0.1237
# Epoch [ 2/ 5], Batch [200], Loss: 0.1114
# Epoch [ 2/ 5], Batch [300], Loss: 0.1108
# Epoch [ 2/ 5], Batch [400], Loss: 0.2082
# Epoch [ 2/ 5], Batch [500], Loss: 0.2521
# Epoch [ 2/ 5], Batch [600], Loss: 0.1495
# Epoch [ 2/ 5], Batch [700], Loss: 0.2726
# Epoch [ 2/ 5], Batch [800], Loss: 0.3155
# Epoch [ 2/ 5], Batch [900], Loss: 0.1584
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1479
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1946
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1417
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1462
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1767
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1104
# Epoch [ 2/ 5], Batch [1600], Loss: 0.2590
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1525
# Epoch [ 2/ 5], Batch [1800], Loss: 0.2093
# Epoch [ 3/ 5], Batch [100], Loss: 0.1408
# Epoch [ 3/ 5], Batch [200], Loss: 0.1157
# Epoch [ 3/ 5], Batch [300], Loss: 0.1468
# Epoch [ 3/ 5], Batch [400], Loss: 0.1315
# Epoch [ 3/ 5], Batch [500], Loss: 0.1350
# Epoch [ 3/ 5], Batch [600], Loss: 0.2522
# Epoch [ 3/ 5], Batch [700], Loss: 0.1386
# Epoch [ 3/ 5], Batch [800], Loss: 0.1541
# Epoch [ 3/ 5], Batch [900], Loss: 0.1264
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1750
# Epoch [ 3/ 5], Batch [1100], Loss: 0.0808
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1084
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1449
# Epoch [ 3/ 5], Batch [1400], Loss: 0.0839
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1107
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1370
# Epoch [ 3/ 5], Batch [1700], Loss: 0.2320
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0904
# Epoch [ 4/ 5], Batch [100], Loss: 0.1633
# Epoch [ 4/ 5], Batch [200], Loss: 0.1743
# Epoch [ 4/ 5], Batch [300], Loss: 0.1187
# Epoch [ 4/ 5], Batch [400], Loss: 0.1698
# Epoch [ 4/ 5], Batch [500], Loss: 0.1387
# Epoch [ 4/ 5], Batch [600], Loss: 0.1267
# Epoch [ 4/ 5], Batch [700], Loss: 0.0855
# Epoch [ 4/ 5], Batch [800], Loss: 0.1525
# Epoch [ 4/ 5], Batch [900], Loss: 0.2648
# Epoch [ 4/ 5], Batch [1000], Loss: 0.2035
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1302
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1274
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1810
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1371
# Epoch [ 4/ 5], Batch [1500], Loss: 0.0942
# Epoch [ 4/ 5], Batch [1600], Loss: 0.0551
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1166
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1830
# Epoch [ 5/ 5], Batch [100], Loss: 0.1478
# Epoch [ 5/ 5], Batch [200], Loss: 0.1602
# Epoch [ 5/ 5], Batch [300], Loss: 0.1218
# Epoch [ 5/ 5], Batch [400], Loss: 0.1132
# Epoch [ 5/ 5], Batch [500], Loss: 0.1483
# Epoch [ 5/ 5], Batch [600], Loss: 0.1933
# Epoch [ 5/ 5], Batch [700], Loss: 0.1616
# Epoch [ 5/ 5], Batch [800], Loss: 0.1243
# Epoch [ 5/ 5], Batch [900], Loss: 0.1482
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1356
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1160
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1329
# Epoch [ 5/ 5], Batch [1300], Loss: 0.0776
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0915
# Epoch [ 5/ 5], Batch [1500], Loss: 0.0989
# Epoch [ 5/ 5], Batch [1600], Loss: 0.3093
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1461
# Epoch [ 5/ 5], Batch [1800], Loss: 0.0853
# F1-scores: train = 0.7136 ; test = 0.7023
#
#
#  Search [3/4]: ********************
#
# Fold [1/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2746
# Epoch [ 1/ 5], Batch [200], Loss: 0.1505
# Epoch [ 1/ 5], Batch [300], Loss: 0.1881
# Epoch [ 1/ 5], Batch [400], Loss: 0.2468
# Epoch [ 1/ 5], Batch [500], Loss: 0.1614
# Epoch [ 1/ 5], Batch [600], Loss: 0.1617
# Epoch [ 1/ 5], Batch [700], Loss: 0.1815
# Epoch [ 1/ 5], Batch [800], Loss: 0.1904
# Epoch [ 1/ 5], Batch [900], Loss: 0.3201
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1597
# Epoch [ 1/ 5], Batch [1100], Loss: 0.0842
# Epoch [ 1/ 5], Batch [1200], Loss: 0.2167
# Epoch [ 1/ 5], Batch [1300], Loss: 0.3242
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1172
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1241
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1038
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1737
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1079
# Epoch [ 2/ 5], Batch [100], Loss: 0.1657
# Epoch [ 2/ 5], Batch [200], Loss: 0.2347
# Epoch [ 2/ 5], Batch [300], Loss: 0.1080
# Epoch [ 2/ 5], Batch [400], Loss: 0.1555
# Epoch [ 2/ 5], Batch [500], Loss: 0.2994
# Epoch [ 2/ 5], Batch [600], Loss: 0.1445
# Epoch [ 2/ 5], Batch [700], Loss: 0.0990
# Epoch [ 2/ 5], Batch [800], Loss: 0.1113
# Epoch [ 2/ 5], Batch [900], Loss: 0.1034
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1735
# Epoch [ 2/ 5], Batch [1100], Loss: 0.2283
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1389
# Epoch [ 2/ 5], Batch [1300], Loss: 0.2173
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1198
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1439
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1373
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1989
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1884
# Epoch [ 3/ 5], Batch [100], Loss: 0.1167
# Epoch [ 3/ 5], Batch [200], Loss: 0.1879
# Epoch [ 3/ 5], Batch [300], Loss: 0.1094
# Epoch [ 3/ 5], Batch [400], Loss: 0.1376
# Epoch [ 3/ 5], Batch [500], Loss: 0.1311
# Epoch [ 3/ 5], Batch [600], Loss: 0.1014
# Epoch [ 3/ 5], Batch [700], Loss: 0.0752
# Epoch [ 3/ 5], Batch [800], Loss: 0.0869
# Epoch [ 3/ 5], Batch [900], Loss: 0.1948
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1171
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1599
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1459
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1927
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1083
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1669
# Epoch [ 3/ 5], Batch [1600], Loss: 0.0932
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1478
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0968
# Epoch [ 4/ 5], Batch [100], Loss: 0.0914
# Epoch [ 4/ 5], Batch [200], Loss: 0.1152
# Epoch [ 4/ 5], Batch [300], Loss: 0.0800
# Epoch [ 4/ 5], Batch [400], Loss: 0.1000
# Epoch [ 4/ 5], Batch [500], Loss: 0.0875
# Epoch [ 4/ 5], Batch [600], Loss: 0.2313
# Epoch [ 4/ 5], Batch [700], Loss: 0.1234
# Epoch [ 4/ 5], Batch [800], Loss: 0.2440
# Epoch [ 4/ 5], Batch [900], Loss: 0.1042
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1883
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1280
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1320
# Epoch [ 4/ 5], Batch [1300], Loss: 0.2031
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1496
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1018
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1427
# Epoch [ 4/ 5], Batch [1700], Loss: 0.2379
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1204
# Epoch [ 5/ 5], Batch [100], Loss: 0.1449
# Epoch [ 5/ 5], Batch [200], Loss: 0.1264
# Epoch [ 5/ 5], Batch [300], Loss: 0.1690
# Epoch [ 5/ 5], Batch [400], Loss: 0.0799
# Epoch [ 5/ 5], Batch [500], Loss: 0.1004
# Epoch [ 5/ 5], Batch [600], Loss: 0.1376
# Epoch [ 5/ 5], Batch [700], Loss: 0.1464
# Epoch [ 5/ 5], Batch [800], Loss: 0.0952
# Epoch [ 5/ 5], Batch [900], Loss: 0.0746
# Epoch [ 5/ 5], Batch [1000], Loss: 0.2342
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1225
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1551
# Epoch [ 5/ 5], Batch [1300], Loss: 0.0881
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1041
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1212
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1293
# Epoch [ 5/ 5], Batch [1700], Loss: 0.2988
# Epoch [ 5/ 5], Batch [1800], Loss: 0.0725
# F1-scores: train = 0.7190 ; test = 0.7138
#
# Fold [2/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1375
# Epoch [ 1/ 5], Batch [200], Loss: 0.1867
# Epoch [ 1/ 5], Batch [300], Loss: 0.2063
# Epoch [ 1/ 5], Batch [400], Loss: 0.2786
# Epoch [ 1/ 5], Batch [500], Loss: 0.1684
# Epoch [ 1/ 5], Batch [600], Loss: 0.1953
# Epoch [ 1/ 5], Batch [700], Loss: 0.1672
# Epoch [ 1/ 5], Batch [800], Loss: 0.1983
# Epoch [ 1/ 5], Batch [900], Loss: 0.1359
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1234
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2505
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1655
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1989
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1598
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1253
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1133
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1511
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1193
# Epoch [ 2/ 5], Batch [100], Loss: 0.1563
# Epoch [ 2/ 5], Batch [200], Loss: 0.2015
# Epoch [ 2/ 5], Batch [300], Loss: 0.1321
# Epoch [ 2/ 5], Batch [400], Loss: 0.2528
# Epoch [ 2/ 5], Batch [500], Loss: 0.1763
# Epoch [ 2/ 5], Batch [600], Loss: 0.2108
# Epoch [ 2/ 5], Batch [700], Loss: 0.2402
# Epoch [ 2/ 5], Batch [800], Loss: 0.0610
# Epoch [ 2/ 5], Batch [900], Loss: 0.1836
# Epoch [ 2/ 5], Batch [1000], Loss: 0.3111
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1581
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1232
# Epoch [ 2/ 5], Batch [1300], Loss: 0.2078
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1234
# Epoch [ 2/ 5], Batch [1500], Loss: 0.2484
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1283
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1609
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1265
# Epoch [ 3/ 5], Batch [100], Loss: 0.1116
# Epoch [ 3/ 5], Batch [200], Loss: 0.1509
# Epoch [ 3/ 5], Batch [300], Loss: 0.1370
# Epoch [ 3/ 5], Batch [400], Loss: 0.1316
# Epoch [ 3/ 5], Batch [500], Loss: 0.3545
# Epoch [ 3/ 5], Batch [600], Loss: 0.2559
# Epoch [ 3/ 5], Batch [700], Loss: 0.1253
# Epoch [ 3/ 5], Batch [800], Loss: 0.0788
# Epoch [ 3/ 5], Batch [900], Loss: 0.1971
# Epoch [ 3/ 5], Batch [1000], Loss: 0.0850
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1691
# Epoch [ 3/ 5], Batch [1200], Loss: 0.0509
# Epoch [ 3/ 5], Batch [1300], Loss: 0.0853
# Epoch [ 3/ 5], Batch [1400], Loss: 0.0861
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1134
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1190
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1539
# Epoch [ 3/ 5], Batch [1800], Loss: 0.3378
# Epoch [ 4/ 5], Batch [100], Loss: 0.1163
# Epoch [ 4/ 5], Batch [200], Loss: 0.1436
# Epoch [ 4/ 5], Batch [300], Loss: 0.0949
# Epoch [ 4/ 5], Batch [400], Loss: 0.0837
# Epoch [ 4/ 5], Batch [500], Loss: 0.1248
# Epoch [ 4/ 5], Batch [600], Loss: 0.1014
# Epoch [ 4/ 5], Batch [700], Loss: 0.1286
# Epoch [ 4/ 5], Batch [800], Loss: 0.1527
# Epoch [ 4/ 5], Batch [900], Loss: 0.1196
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1278
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1836
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1756
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1731
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1606
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1252
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1129
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1438
# Epoch [ 4/ 5], Batch [1800], Loss: 0.0969
# Epoch [ 5/ 5], Batch [100], Loss: 0.1077
# Epoch [ 5/ 5], Batch [200], Loss: 0.1739
# Epoch [ 5/ 5], Batch [300], Loss: 0.2267
# Epoch [ 5/ 5], Batch [400], Loss: 0.1123
# Epoch [ 5/ 5], Batch [500], Loss: 0.0709
# Epoch [ 5/ 5], Batch [600], Loss: 0.0591
# Epoch [ 5/ 5], Batch [700], Loss: 0.1995
# Epoch [ 5/ 5], Batch [800], Loss: 0.0630
# Epoch [ 5/ 5], Batch [900], Loss: 0.0795
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1063
# Epoch [ 5/ 5], Batch [1100], Loss: 0.2406
# Epoch [ 5/ 5], Batch [1200], Loss: 0.0736
# Epoch [ 5/ 5], Batch [1300], Loss: 0.3023
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0900
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1400
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1246
# Epoch [ 5/ 5], Batch [1700], Loss: 0.3464
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1237
# F1-scores: train = 0.3428 ; test = 0.3280
#
# Fold [3/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2684
# Epoch [ 1/ 5], Batch [200], Loss: 0.2088
# Epoch [ 1/ 5], Batch [300], Loss: 0.2039
# Epoch [ 1/ 5], Batch [400], Loss: 0.2491
# Epoch [ 1/ 5], Batch [500], Loss: 0.1508
# Epoch [ 1/ 5], Batch [600], Loss: 0.1259
# Epoch [ 1/ 5], Batch [700], Loss: 0.2803
# Epoch [ 1/ 5], Batch [800], Loss: 0.1272
# Epoch [ 1/ 5], Batch [900], Loss: 0.1828
# Epoch [ 1/ 5], Batch [1000], Loss: 0.2067
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1653
# Epoch [ 1/ 5], Batch [1200], Loss: 0.2065
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1270
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1513
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1813
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1370
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1466
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1496
# Epoch [ 2/ 5], Batch [100], Loss: 0.2379
# Epoch [ 2/ 5], Batch [200], Loss: 0.1745
# Epoch [ 2/ 5], Batch [300], Loss: 0.2690
# Epoch [ 2/ 5], Batch [400], Loss: 0.1812
# Epoch [ 2/ 5], Batch [500], Loss: 0.1114
# Epoch [ 2/ 5], Batch [600], Loss: 0.1718
# Epoch [ 2/ 5], Batch [700], Loss: 0.1276
# Epoch [ 2/ 5], Batch [800], Loss: 0.1889
# Epoch [ 2/ 5], Batch [900], Loss: 0.2344
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1383
# Epoch [ 2/ 5], Batch [1100], Loss: 0.0896
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1681
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1635
# Epoch [ 2/ 5], Batch [1400], Loss: 0.0911
# Epoch [ 2/ 5], Batch [1500], Loss: 0.2401
# Epoch [ 2/ 5], Batch [1600], Loss: 0.0620
# Epoch [ 2/ 5], Batch [1700], Loss: 0.2662
# Epoch [ 2/ 5], Batch [1800], Loss: 0.0953
# Epoch [ 3/ 5], Batch [100], Loss: 0.2989
# Epoch [ 3/ 5], Batch [200], Loss: 0.1431
# Epoch [ 3/ 5], Batch [300], Loss: 0.1334
# Epoch [ 3/ 5], Batch [400], Loss: 0.1835
# Epoch [ 3/ 5], Batch [500], Loss: 0.0943
# Epoch [ 3/ 5], Batch [600], Loss: 0.1825
# Epoch [ 3/ 5], Batch [700], Loss: 0.1165
# Epoch [ 3/ 5], Batch [800], Loss: 0.1262
# Epoch [ 3/ 5], Batch [900], Loss: 0.1071
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1425
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1457
# Epoch [ 3/ 5], Batch [1200], Loss: 0.0998
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1020
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1614
# Epoch [ 3/ 5], Batch [1500], Loss: 0.2729
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1390
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1262
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0816
# Epoch [ 4/ 5], Batch [100], Loss: 0.0631
# Epoch [ 4/ 5], Batch [200], Loss: 0.1626
# Epoch [ 4/ 5], Batch [300], Loss: 0.0750
# Epoch [ 4/ 5], Batch [400], Loss: 0.1900
# Epoch [ 4/ 5], Batch [500], Loss: 0.0998
# Epoch [ 4/ 5], Batch [600], Loss: 0.1173
# Epoch [ 4/ 5], Batch [700], Loss: 0.1535
# Epoch [ 4/ 5], Batch [800], Loss: 0.0676
# Epoch [ 4/ 5], Batch [900], Loss: 0.1706
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1349
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1118
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1666
# Epoch [ 4/ 5], Batch [1300], Loss: 0.0986
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1824
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1159
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1273
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1239
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1375
# Epoch [ 5/ 5], Batch [100], Loss: 0.1389
# Epoch [ 5/ 5], Batch [200], Loss: 0.2579
# Epoch [ 5/ 5], Batch [300], Loss: 0.0742
# Epoch [ 5/ 5], Batch [400], Loss: 0.1950
# Epoch [ 5/ 5], Batch [500], Loss: 0.1894
# Epoch [ 5/ 5], Batch [600], Loss: 0.1341
# Epoch [ 5/ 5], Batch [700], Loss: 0.1713
# Epoch [ 5/ 5], Batch [800], Loss: 0.0817
# Epoch [ 5/ 5], Batch [900], Loss: 0.0986
# Epoch [ 5/ 5], Batch [1000], Loss: 0.0857
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1460
# Epoch [ 5/ 5], Batch [1200], Loss: 0.0912
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1187
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1827
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1261
# Epoch [ 5/ 5], Batch [1600], Loss: 0.2387
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1367
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1540
# F1-scores: train = 0.5225 ; test = 0.5067
#
# Fold [4/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2297
# Epoch [ 1/ 5], Batch [200], Loss: 0.3365
# Epoch [ 1/ 5], Batch [300], Loss: 0.2029
# Epoch [ 1/ 5], Batch [400], Loss: 0.2112
# Epoch [ 1/ 5], Batch [500], Loss: 0.1903
# Epoch [ 1/ 5], Batch [600], Loss: 0.1973
# Epoch [ 1/ 5], Batch [700], Loss: 0.1343
# Epoch [ 1/ 5], Batch [800], Loss: 0.1754
# Epoch [ 1/ 5], Batch [900], Loss: 0.2963
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1938
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2295
# Epoch [ 1/ 5], Batch [1200], Loss: 0.2076
# Epoch [ 1/ 5], Batch [1300], Loss: 0.2283
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1746
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1319
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1919
# Epoch [ 1/ 5], Batch [1700], Loss: 0.2002
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2958
# Epoch [ 2/ 5], Batch [100], Loss: 0.3306
# Epoch [ 2/ 5], Batch [200], Loss: 0.1998
# Epoch [ 2/ 5], Batch [300], Loss: 0.1252
# Epoch [ 2/ 5], Batch [400], Loss: 0.1293
# Epoch [ 2/ 5], Batch [500], Loss: 0.1825
# Epoch [ 2/ 5], Batch [600], Loss: 0.2176
# Epoch [ 2/ 5], Batch [700], Loss: 0.1265
# Epoch [ 2/ 5], Batch [800], Loss: 0.1018
# Epoch [ 2/ 5], Batch [900], Loss: 0.1213
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1124
# Epoch [ 2/ 5], Batch [1100], Loss: 0.2041
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1754
# Epoch [ 2/ 5], Batch [1300], Loss: 0.0799
# Epoch [ 2/ 5], Batch [1400], Loss: 0.0620
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1039
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1575
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1144
# Epoch [ 2/ 5], Batch [1800], Loss: 0.0621
# Epoch [ 3/ 5], Batch [100], Loss: 0.1203
# Epoch [ 3/ 5], Batch [200], Loss: 0.0924
# Epoch [ 3/ 5], Batch [300], Loss: 0.1507
# Epoch [ 3/ 5], Batch [400], Loss: 0.1612
# Epoch [ 3/ 5], Batch [500], Loss: 0.4226
# Epoch [ 3/ 5], Batch [600], Loss: 0.1548
# Epoch [ 3/ 5], Batch [700], Loss: 0.0994
# Epoch [ 3/ 5], Batch [800], Loss: 0.1468
# Epoch [ 3/ 5], Batch [900], Loss: 0.1928
# Epoch [ 3/ 5], Batch [1000], Loss: 0.1389
# Epoch [ 3/ 5], Batch [1100], Loss: 0.0853
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1564
# Epoch [ 3/ 5], Batch [1300], Loss: 0.0594
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1283
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1602
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1385
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1767
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1346
# Epoch [ 4/ 5], Batch [100], Loss: 0.1539
# Epoch [ 4/ 5], Batch [200], Loss: 0.1488
# Epoch [ 4/ 5], Batch [300], Loss: 0.3189
# Epoch [ 4/ 5], Batch [400], Loss: 0.1406
# Epoch [ 4/ 5], Batch [500], Loss: 0.1032
# Epoch [ 4/ 5], Batch [600], Loss: 0.1384
# Epoch [ 4/ 5], Batch [700], Loss: 0.1154
# Epoch [ 4/ 5], Batch [800], Loss: 0.0977
# Epoch [ 4/ 5], Batch [900], Loss: 0.0834
# Epoch [ 4/ 5], Batch [1000], Loss: 0.0861
# Epoch [ 4/ 5], Batch [1100], Loss: 0.0895
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1732
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1062
# Epoch [ 4/ 5], Batch [1400], Loss: 0.0865
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1392
# Epoch [ 4/ 5], Batch [1600], Loss: 0.0959
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1753
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1769
# Epoch [ 5/ 5], Batch [100], Loss: 0.1711
# Epoch [ 5/ 5], Batch [200], Loss: 0.0810
# Epoch [ 5/ 5], Batch [300], Loss: 0.1624
# Epoch [ 5/ 5], Batch [400], Loss: 0.1069
# Epoch [ 5/ 5], Batch [500], Loss: 0.2306
# Epoch [ 5/ 5], Batch [600], Loss: 0.2222
# Epoch [ 5/ 5], Batch [700], Loss: 0.1224
# Epoch [ 5/ 5], Batch [800], Loss: 0.1151
# Epoch [ 5/ 5], Batch [900], Loss: 0.1111
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1294
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1636
# Epoch [ 5/ 5], Batch [1200], Loss: 0.2016
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1625
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1944
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1293
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1618
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1426
# Epoch [ 5/ 5], Batch [1800], Loss: 0.0948
# F1-scores: train = 0.2877 ; test = 0.2815
#
#
#  Search [4/4]: ********************
#
# Fold [1/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1526
# Epoch [ 1/ 5], Batch [200], Loss: 0.2661
# Epoch [ 1/ 5], Batch [300], Loss: 0.1237
# Epoch [ 1/ 5], Batch [400], Loss: 0.1774
# Epoch [ 1/ 5], Batch [500], Loss: 0.1839
# Epoch [ 1/ 5], Batch [600], Loss: 0.1179
# Epoch [ 1/ 5], Batch [700], Loss: 0.1136
# Epoch [ 1/ 5], Batch [800], Loss: 0.1868
# Epoch [ 1/ 5], Batch [900], Loss: 0.1572
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1671
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2426
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1396
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1051
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1538
# Epoch [ 1/ 5], Batch [1500], Loss: 0.0820
# Epoch [ 1/ 5], Batch [1600], Loss: 0.2390
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1664
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1229
# Epoch [ 2/ 5], Batch [100], Loss: 0.1516
# Epoch [ 2/ 5], Batch [200], Loss: 0.1363
# Epoch [ 2/ 5], Batch [300], Loss: 0.1101
# Epoch [ 2/ 5], Batch [400], Loss: 0.1427
# Epoch [ 2/ 5], Batch [500], Loss: 0.0910
# Epoch [ 2/ 5], Batch [600], Loss: 0.1236
# Epoch [ 2/ 5], Batch [700], Loss: 0.1111
# Epoch [ 2/ 5], Batch [800], Loss: 0.2031
# Epoch [ 2/ 5], Batch [900], Loss: 0.1347
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1374
# Epoch [ 2/ 5], Batch [1100], Loss: 0.0885
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1018
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1233
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1230
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1305
# Epoch [ 2/ 5], Batch [1600], Loss: 0.0595
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1234
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1121
# Epoch [ 3/ 5], Batch [100], Loss: 0.1376
# Epoch [ 3/ 5], Batch [200], Loss: 0.1949
# Epoch [ 3/ 5], Batch [300], Loss: 0.0499
# Epoch [ 3/ 5], Batch [400], Loss: 0.0553
# Epoch [ 3/ 5], Batch [500], Loss: 0.1596
# Epoch [ 3/ 5], Batch [600], Loss: 0.0988
# Epoch [ 3/ 5], Batch [700], Loss: 0.1351
# Epoch [ 3/ 5], Batch [800], Loss: 0.0654
# Epoch [ 3/ 5], Batch [900], Loss: 0.1245
# Epoch [ 3/ 5], Batch [1000], Loss: 0.0598
# Epoch [ 3/ 5], Batch [1100], Loss: 0.0863
# Epoch [ 3/ 5], Batch [1200], Loss: 0.0970
# Epoch [ 3/ 5], Batch [1300], Loss: 0.0522
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1230
# Epoch [ 3/ 5], Batch [1500], Loss: 0.0899
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1530
# Epoch [ 3/ 5], Batch [1700], Loss: 0.0733
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1456
# Epoch [ 4/ 5], Batch [100], Loss: 0.1470
# Epoch [ 4/ 5], Batch [200], Loss: 0.1321
# Epoch [ 4/ 5], Batch [300], Loss: 0.1938
# Epoch [ 4/ 5], Batch [400], Loss: 0.1833
# Epoch [ 4/ 5], Batch [500], Loss: 0.0998
# Epoch [ 4/ 5], Batch [600], Loss: 0.1305
# Epoch [ 4/ 5], Batch [700], Loss: 0.1411
# Epoch [ 4/ 5], Batch [800], Loss: 0.0847
# Epoch [ 4/ 5], Batch [900], Loss: 0.0548
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1166
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1726
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1465
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1306
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1157
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1615
# Epoch [ 4/ 5], Batch [1600], Loss: 0.0764
# Epoch [ 4/ 5], Batch [1700], Loss: 0.1198
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1138
# Epoch [ 5/ 5], Batch [100], Loss: 0.0812
# Epoch [ 5/ 5], Batch [200], Loss: 0.1382
# Epoch [ 5/ 5], Batch [300], Loss: 0.1023
# Epoch [ 5/ 5], Batch [400], Loss: 0.1113
# Epoch [ 5/ 5], Batch [500], Loss: 0.0576
# Epoch [ 5/ 5], Batch [600], Loss: 0.1586
# Epoch [ 5/ 5], Batch [700], Loss: 0.1312
# Epoch [ 5/ 5], Batch [800], Loss: 0.1117
# Epoch [ 5/ 5], Batch [900], Loss: 0.2600
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1574
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1012
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1631
# Epoch [ 5/ 5], Batch [1300], Loss: 0.1915
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0725
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1101
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1342
# Epoch [ 5/ 5], Batch [1700], Loss: 0.0876
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1639
# F1-scores: train = 0.6395 ; test = 0.6194
#
# Fold [2/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.1534
# Epoch [ 1/ 5], Batch [200], Loss: 0.3560
# Epoch [ 1/ 5], Batch [300], Loss: 0.0981
# Epoch [ 1/ 5], Batch [400], Loss: 0.1049
# Epoch [ 1/ 5], Batch [500], Loss: 0.1978
# Epoch [ 1/ 5], Batch [600], Loss: 0.2319
# Epoch [ 1/ 5], Batch [700], Loss: 0.1681
# Epoch [ 1/ 5], Batch [800], Loss: 0.1434
# Epoch [ 1/ 5], Batch [900], Loss: 0.1442
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1329
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1792
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1649
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1272
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1208
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1212
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1871
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1509
# Epoch [ 1/ 5], Batch [1800], Loss: 0.2330
# Epoch [ 2/ 5], Batch [100], Loss: 0.1812
# Epoch [ 2/ 5], Batch [200], Loss: 0.1551
# Epoch [ 2/ 5], Batch [300], Loss: 0.1728
# Epoch [ 2/ 5], Batch [400], Loss: 0.1190
# Epoch [ 2/ 5], Batch [500], Loss: 0.2273
# Epoch [ 2/ 5], Batch [600], Loss: 0.1532
# Epoch [ 2/ 5], Batch [700], Loss: 0.1294
# Epoch [ 2/ 5], Batch [800], Loss: 0.0752
# Epoch [ 2/ 5], Batch [900], Loss: 0.1463
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1127
# Epoch [ 2/ 5], Batch [1100], Loss: 0.0894
# Epoch [ 2/ 5], Batch [1200], Loss: 0.1067
# Epoch [ 2/ 5], Batch [1300], Loss: 0.1455
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1440
# Epoch [ 2/ 5], Batch [1500], Loss: 0.0727
# Epoch [ 2/ 5], Batch [1600], Loss: 0.2233
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1650
# Epoch [ 2/ 5], Batch [1800], Loss: 0.0859
# Epoch [ 3/ 5], Batch [100], Loss: 0.0952
# Epoch [ 3/ 5], Batch [200], Loss: 0.1039
# Epoch [ 3/ 5], Batch [300], Loss: 0.2305
# Epoch [ 3/ 5], Batch [400], Loss: 0.1140
# Epoch [ 3/ 5], Batch [500], Loss: 0.1753
# Epoch [ 3/ 5], Batch [600], Loss: 0.1545
# Epoch [ 3/ 5], Batch [700], Loss: 0.1043
# Epoch [ 3/ 5], Batch [800], Loss: 0.1920
# Epoch [ 3/ 5], Batch [900], Loss: 0.1102
# Epoch [ 3/ 5], Batch [1000], Loss: 0.2825
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1003
# Epoch [ 3/ 5], Batch [1200], Loss: 0.0813
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1010
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1001
# Epoch [ 3/ 5], Batch [1500], Loss: 0.0526
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1557
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1409
# Epoch [ 3/ 5], Batch [1800], Loss: 0.1004
# Epoch [ 4/ 5], Batch [100], Loss: 0.1121
# Epoch [ 4/ 5], Batch [200], Loss: 0.0692
# Epoch [ 4/ 5], Batch [300], Loss: 0.1987
# Epoch [ 4/ 5], Batch [400], Loss: 0.1805
# Epoch [ 4/ 5], Batch [500], Loss: 0.0714
# Epoch [ 4/ 5], Batch [600], Loss: 0.0933
# Epoch [ 4/ 5], Batch [700], Loss: 0.1194
# Epoch [ 4/ 5], Batch [800], Loss: 0.1505
# Epoch [ 4/ 5], Batch [900], Loss: 0.1335
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1140
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1504
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1017
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1073
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1496
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1486
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1299
# Epoch [ 4/ 5], Batch [1700], Loss: 0.0807
# Epoch [ 4/ 5], Batch [1800], Loss: 0.0904
# Epoch [ 5/ 5], Batch [100], Loss: 0.1823
# Epoch [ 5/ 5], Batch [200], Loss: 0.1655
# Epoch [ 5/ 5], Batch [300], Loss: 0.1427
# Epoch [ 5/ 5], Batch [400], Loss: 0.0992
# Epoch [ 5/ 5], Batch [500], Loss: 0.0707
# Epoch [ 5/ 5], Batch [600], Loss: 0.2322
# Epoch [ 5/ 5], Batch [700], Loss: 0.1610
# Epoch [ 5/ 5], Batch [800], Loss: 0.0972
# Epoch [ 5/ 5], Batch [900], Loss: 0.2024
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1039
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1291
# Epoch [ 5/ 5], Batch [1200], Loss: 0.1032
# Epoch [ 5/ 5], Batch [1300], Loss: 0.0782
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0946
# Epoch [ 5/ 5], Batch [1500], Loss: 0.0890
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1422
# Epoch [ 5/ 5], Batch [1700], Loss: 0.1228
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1378
# F1-scores: train = 0.3529 ; test = 0.3626
#
# Fold [3/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2155
# Epoch [ 1/ 5], Batch [200], Loss: 0.1754
# Epoch [ 1/ 5], Batch [300], Loss: 0.0858
# Epoch [ 1/ 5], Batch [400], Loss: 0.1418
# Epoch [ 1/ 5], Batch [500], Loss: 0.1680
# Epoch [ 1/ 5], Batch [600], Loss: 0.1474
# Epoch [ 1/ 5], Batch [700], Loss: 0.1263
# Epoch [ 1/ 5], Batch [800], Loss: 0.1081
# Epoch [ 1/ 5], Batch [900], Loss: 0.1165
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1375
# Epoch [ 1/ 5], Batch [1100], Loss: 0.2549
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1308
# Epoch [ 1/ 5], Batch [1300], Loss: 0.2102
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1315
# Epoch [ 1/ 5], Batch [1500], Loss: 0.1332
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1610
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1385
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1165
# Epoch [ 2/ 5], Batch [100], Loss: 0.1449
# Epoch [ 2/ 5], Batch [200], Loss: 0.0667
# Epoch [ 2/ 5], Batch [300], Loss: 0.0927
# Epoch [ 2/ 5], Batch [400], Loss: 0.1140
# Epoch [ 2/ 5], Batch [500], Loss: 0.2045
# Epoch [ 2/ 5], Batch [600], Loss: 0.1554
# Epoch [ 2/ 5], Batch [700], Loss: 0.1793
# Epoch [ 2/ 5], Batch [800], Loss: 0.1043
# Epoch [ 2/ 5], Batch [900], Loss: 0.1309
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1589
# Epoch [ 2/ 5], Batch [1100], Loss: 0.1188
# Epoch [ 2/ 5], Batch [1200], Loss: 0.2140
# Epoch [ 2/ 5], Batch [1300], Loss: 0.2531
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1391
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1820
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1424
# Epoch [ 2/ 5], Batch [1700], Loss: 0.0969
# Epoch [ 2/ 5], Batch [1800], Loss: 0.1243
# Epoch [ 3/ 5], Batch [100], Loss: 0.1853
# Epoch [ 3/ 5], Batch [200], Loss: 0.1603
# Epoch [ 3/ 5], Batch [300], Loss: 0.1636
# Epoch [ 3/ 5], Batch [400], Loss: 0.1723
# Epoch [ 3/ 5], Batch [500], Loss: 0.0925
# Epoch [ 3/ 5], Batch [600], Loss: 0.1634
# Epoch [ 3/ 5], Batch [700], Loss: 0.0907
# Epoch [ 3/ 5], Batch [800], Loss: 0.1378
# Epoch [ 3/ 5], Batch [900], Loss: 0.2330
# Epoch [ 3/ 5], Batch [1000], Loss: 0.0819
# Epoch [ 3/ 5], Batch [1100], Loss: 0.0599
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1101
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1498
# Epoch [ 3/ 5], Batch [1400], Loss: 0.1381
# Epoch [ 3/ 5], Batch [1500], Loss: 0.1083
# Epoch [ 3/ 5], Batch [1600], Loss: 0.1525
# Epoch [ 3/ 5], Batch [1700], Loss: 0.1108
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0684
# Epoch [ 4/ 5], Batch [100], Loss: 0.1337
# Epoch [ 4/ 5], Batch [200], Loss: 0.1363
# Epoch [ 4/ 5], Batch [300], Loss: 0.1099
# Epoch [ 4/ 5], Batch [400], Loss: 0.1505
# Epoch [ 4/ 5], Batch [500], Loss: 0.1331
# Epoch [ 4/ 5], Batch [600], Loss: 0.0294
# Epoch [ 4/ 5], Batch [700], Loss: 0.0921
# Epoch [ 4/ 5], Batch [800], Loss: 0.2480
# Epoch [ 4/ 5], Batch [900], Loss: 0.1041
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1304
# Epoch [ 4/ 5], Batch [1100], Loss: 0.1707
# Epoch [ 4/ 5], Batch [1200], Loss: 0.0856
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1753
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1954
# Epoch [ 4/ 5], Batch [1500], Loss: 0.0662
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1774
# Epoch [ 4/ 5], Batch [1700], Loss: 0.0925
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1271
# Epoch [ 5/ 5], Batch [100], Loss: 0.0845
# Epoch [ 5/ 5], Batch [200], Loss: 0.0847
# Epoch [ 5/ 5], Batch [300], Loss: 0.0883
# Epoch [ 5/ 5], Batch [400], Loss: 0.1588
# Epoch [ 5/ 5], Batch [500], Loss: 0.0557
# Epoch [ 5/ 5], Batch [600], Loss: 0.1340
# Epoch [ 5/ 5], Batch [700], Loss: 0.1108
# Epoch [ 5/ 5], Batch [800], Loss: 0.1227
# Epoch [ 5/ 5], Batch [900], Loss: 0.1822
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1060
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1726
# Epoch [ 5/ 5], Batch [1200], Loss: 0.2414
# Epoch [ 5/ 5], Batch [1300], Loss: 0.0728
# Epoch [ 5/ 5], Batch [1400], Loss: 0.0592
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1132
# Epoch [ 5/ 5], Batch [1600], Loss: 0.1677
# Epoch [ 5/ 5], Batch [1700], Loss: 0.0824
# Epoch [ 5/ 5], Batch [1800], Loss: 0.1331
# F1-scores: train = 0.6613 ; test = 0.6316
#
# Fold [4/4]: --------------------
# Epoch [ 1/ 5], Batch [100], Loss: 0.2277
# Epoch [ 1/ 5], Batch [200], Loss: 0.2834
# Epoch [ 1/ 5], Batch [300], Loss: 0.1674
# Epoch [ 1/ 5], Batch [400], Loss: 0.0631
# Epoch [ 1/ 5], Batch [500], Loss: 0.1414
# Epoch [ 1/ 5], Batch [600], Loss: 0.1755
# Epoch [ 1/ 5], Batch [700], Loss: 0.1566
# Epoch [ 1/ 5], Batch [800], Loss: 0.0797
# Epoch [ 1/ 5], Batch [900], Loss: 0.1485
# Epoch [ 1/ 5], Batch [1000], Loss: 0.1943
# Epoch [ 1/ 5], Batch [1100], Loss: 0.1197
# Epoch [ 1/ 5], Batch [1200], Loss: 0.1754
# Epoch [ 1/ 5], Batch [1300], Loss: 0.1153
# Epoch [ 1/ 5], Batch [1400], Loss: 0.1651
# Epoch [ 1/ 5], Batch [1500], Loss: 0.0832
# Epoch [ 1/ 5], Batch [1600], Loss: 0.1305
# Epoch [ 1/ 5], Batch [1700], Loss: 0.1169
# Epoch [ 1/ 5], Batch [1800], Loss: 0.1612
# Epoch [ 2/ 5], Batch [100], Loss: 0.1769
# Epoch [ 2/ 5], Batch [200], Loss: 0.0790
# Epoch [ 2/ 5], Batch [300], Loss: 0.1121
# Epoch [ 2/ 5], Batch [400], Loss: 0.1105
# Epoch [ 2/ 5], Batch [500], Loss: 0.1108
# Epoch [ 2/ 5], Batch [600], Loss: 0.1696
# Epoch [ 2/ 5], Batch [700], Loss: 0.0826
# Epoch [ 2/ 5], Batch [800], Loss: 0.1162
# Epoch [ 2/ 5], Batch [900], Loss: 0.1480
# Epoch [ 2/ 5], Batch [1000], Loss: 0.1157
# Epoch [ 2/ 5], Batch [1100], Loss: 0.0665
# Epoch [ 2/ 5], Batch [1200], Loss: 0.0934
# Epoch [ 2/ 5], Batch [1300], Loss: 0.0708
# Epoch [ 2/ 5], Batch [1400], Loss: 0.1263
# Epoch [ 2/ 5], Batch [1500], Loss: 0.1074
# Epoch [ 2/ 5], Batch [1600], Loss: 0.1745
# Epoch [ 2/ 5], Batch [1700], Loss: 0.1002
# Epoch [ 2/ 5], Batch [1800], Loss: 0.2098
# Epoch [ 3/ 5], Batch [100], Loss: 0.1141
# Epoch [ 3/ 5], Batch [200], Loss: 0.0890
# Epoch [ 3/ 5], Batch [300], Loss: 0.1356
# Epoch [ 3/ 5], Batch [400], Loss: 0.1481
# Epoch [ 3/ 5], Batch [500], Loss: 0.0994
# Epoch [ 3/ 5], Batch [600], Loss: 0.2202
# Epoch [ 3/ 5], Batch [700], Loss: 0.0878
# Epoch [ 3/ 5], Batch [800], Loss: 0.0913
# Epoch [ 3/ 5], Batch [900], Loss: 0.2266
# Epoch [ 3/ 5], Batch [1000], Loss: 0.0901
# Epoch [ 3/ 5], Batch [1100], Loss: 0.1143
# Epoch [ 3/ 5], Batch [1200], Loss: 0.1298
# Epoch [ 3/ 5], Batch [1300], Loss: 0.1207
# Epoch [ 3/ 5], Batch [1400], Loss: 0.0649
# Epoch [ 3/ 5], Batch [1500], Loss: 0.0897
# Epoch [ 3/ 5], Batch [1600], Loss: 0.0964
# Epoch [ 3/ 5], Batch [1700], Loss: 0.2976
# Epoch [ 3/ 5], Batch [1800], Loss: 0.0854
# Epoch [ 4/ 5], Batch [100], Loss: 0.0883
# Epoch [ 4/ 5], Batch [200], Loss: 0.0868
# Epoch [ 4/ 5], Batch [300], Loss: 0.1181
# Epoch [ 4/ 5], Batch [400], Loss: 0.0955
# Epoch [ 4/ 5], Batch [500], Loss: 0.1399
# Epoch [ 4/ 5], Batch [600], Loss: 0.0787
# Epoch [ 4/ 5], Batch [700], Loss: 0.0888
# Epoch [ 4/ 5], Batch [800], Loss: 0.1074
# Epoch [ 4/ 5], Batch [900], Loss: 0.1354
# Epoch [ 4/ 5], Batch [1000], Loss: 0.1997
# Epoch [ 4/ 5], Batch [1100], Loss: 0.2047
# Epoch [ 4/ 5], Batch [1200], Loss: 0.1518
# Epoch [ 4/ 5], Batch [1300], Loss: 0.1438
# Epoch [ 4/ 5], Batch [1400], Loss: 0.1117
# Epoch [ 4/ 5], Batch [1500], Loss: 0.1346
# Epoch [ 4/ 5], Batch [1600], Loss: 0.1231
# Epoch [ 4/ 5], Batch [1700], Loss: 0.0593
# Epoch [ 4/ 5], Batch [1800], Loss: 0.1593
# Epoch [ 5/ 5], Batch [100], Loss: 0.1829
# Epoch [ 5/ 5], Batch [200], Loss: 0.1232
# Epoch [ 5/ 5], Batch [300], Loss: 0.0844
# Epoch [ 5/ 5], Batch [400], Loss: 0.1922
# Epoch [ 5/ 5], Batch [500], Loss: 0.0757
# Epoch [ 5/ 5], Batch [600], Loss: 0.1807
# Epoch [ 5/ 5], Batch [700], Loss: 0.1014
# Epoch [ 5/ 5], Batch [800], Loss: 0.1071
# Epoch [ 5/ 5], Batch [900], Loss: 0.0682
# Epoch [ 5/ 5], Batch [1000], Loss: 0.1034
# Epoch [ 5/ 5], Batch [1100], Loss: 0.1557
# Epoch [ 5/ 5], Batch [1200], Loss: 0.2052
# Epoch [ 5/ 5], Batch [1300], Loss: 0.3061
# Epoch [ 5/ 5], Batch [1400], Loss: 0.1584
# Epoch [ 5/ 5], Batch [1500], Loss: 0.1115
# Epoch [ 5/ 5], Batch [1600], Loss: 0.0815
# Epoch [ 5/ 5], Batch [1700], Loss: 0.0783
# Epoch [ 5/ 5], Batch [1800], Loss: 0.2143
# F1-scores: train = 0.6858 ; test = 0.6679
#
# Grid-search effectuated in 3206.237 seconds

# %% [markdown]
# # 3 Post-process the labels

# %% [markdown]
# ## 3.1 Create predictions array

# %%
def predict_label(data_loader, model):
    """
    Create predicted label on the data with the model
    Input:
        data_loader: a PyTorch DataLoader with a roadDataset to label
                     the batch_size HAVE to be equal to (image_size//PATCH_SIZE)**2, i.e. one image per batch
        model: a PyTorch Module to make the prediction
    Output:
        prediction: a label array with the prediction of the images of the data_loader
    """
    # Change model to 'eval' mode (useful for Dropout and BatchNormalization)
    model.eval()
    
    prediction = []
    # Loop on each batch/image
    for images, _, _ in data_loader:
        images = Variable(images)
        preds = model(images).data
        
        preds[preds >= 0.5] = 1
        preds[preds < 0.5] = 0
        
        prediction.append(preds.numpy().reshape((int(np.sqrt(preds.shape[0])), -1)))
    return np.asarray(prediction)

# %%
dataset = roadDataset(tx.reshape((-1,window_size,window_size,tx.shape[-1])), ty.ravel())
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=PATCH_NUM**2, 
                                          shuffle=False)
start = time.time()
prediction = predict_label(data_loader=data_loader, model=network)
end = time.time()
print("Prediction computed in %.3f seconds." % (end - start))
print(prediction.shape)
# Out:
# Prediction computed in 107.388 seconds.
# (100, 25, 25)

# %%
img_num = 0

plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(x_train[img_num])
plt.title("Image")
plt.subplot(132)
plt.imshow(y_train[img_num], cmap='gray')
plt.title("Label")
plt.subplot(133)
plt.imshow(prediction[img_num], cmap='gray')
plt.title("Prediction")

print("Accuracy on image #%d: %.2f %%" % (img_num, 100*(y_train[img_num] == prediction[img_num]).mean()))
print("F1-score on image #%d: %f" % (img_num, f1_score(y_train[img_num].ravel(), prediction[img_num].ravel())))
# Out:
# Accuracy on image #0: 87.52 %
# F1-score on image #0: 0.721429

# %% [markdown]
# ## 3.2 Process the predictions

# %%
def keep_side_connected(prediction, connectivity=2):
    """
    Return modified predictions, where every blob of road not connected to the side is changed as background
    Input:
        prediction: the array containing the predictions; size:(IMAGE_SIZE/PATCH_SIZE, IMAGE_SIZE/PATCH_SIZE)
        connectivity: the type of connectivity, 1 is 4-connected, and 2 is 8 (default: 2)
    Output:
        new_pred: the modified prediction, with the blobs of roads deleted; size:(IMAGE_SIZE/PATCH_SIZE, IMAGE_SIZE/PATCH_SIZE)
    """
    new_pred, num_label = measure.label(prediction, connectivity=connectivity, return_num=True)
    
    to_keep = []
    # Loop on the sides to see which segments are connected to them
    # Top side
    for i in range(new_pred.shape[1]):
        if new_pred[0,i] not in to_keep:
            to_keep.append(new_pred[0,i])
    # Right side
    for i in range(new_pred.shape[0]): 
        if new_pred[i,-1] not in to_keep:
            to_keep.append(new_pred[i,-1])
    # Bottom side
    for i in range(new_pred.shape[1]): 
        if new_pred[-1,i] not in to_keep:
            to_keep.append(new_pred[-1,i])
    # Left side
    for i in range(new_pred.shape[1]): 
        if new_pred[i,0] not in to_keep:
            to_keep.append(new_pred[i,0])
    
    # Keep the roads connected to the side of the image
    for label in range(1, num_label+1):
        if label in to_keep:
            new_pred[new_pred==label] = 1
        else:
            new_pred[new_pred==label] = 0
    return new_pred

def neighbor_road(prediction, threshold=4, connectivity=2):
    """
    For each pixel in prediction, if its neighborhood contains at least 'threshold' road pixels, 
    then give it a road label
    Does not consider side pixels, and if a pixel is originally road, it stays that way
    Input:
        prediction: the array containing the predictions; size:(IMAGE_SIZE/PATCH_SIZE, IMAGE_SIZE/PATCH_SIZE)
        threshold: the number of pixels to be road before assigning road to a pixel (default: 4)
        connectivity: the type of connectivity, 1 is 4-connected, and 2 is 8 (default: 2)
    Output:
        new_pred: the modified prediction; size:(IMAGE_SIZE/PATCH_SIZE, IMAGE_SIZE/PATCH_SIZE)
    """
    if connectivity == 1:
        neighb_mask = np.array([
            [False, True, False],
            [True, False, True],
            [False, True, False]
        ])
    elif connectivity == 2:
        neighb_mask = np.array([
            [True, True, True],
            [True, False, True],
            [True, True, True]
        ])
    new_pred = prediction.copy()
    for i in range(1, prediction.shape[0]-1):
        for j in range(1, prediction.shape[1]-1):
            neighborhood = prediction[i-1:i+2,j-1:j+2]
            neighborhood = neighborhood[neighb_mask]
            if neighborhood.sum() >= threshold:
                new_pred[i,j] = 1
    return new_pred

# %%
morphed_pred = prediction.copy()
# struct = np.array([
#     [False, False, False],
#     [False, True, True],
#     [False, True, False]])
for i in range(morphed_pred.shape[0]):
#     morphed_pred[i] = morph.binary_opening(morphed_pred[i], structure=struct)
#     morphed_pred[i] = morph.binary_closing(morphed_pred[i], structure=struct)
#     morphed_pred[i] = morph.binary_fill_holes(morphed_pred[i], structure=struct)
    morphed_pred[i] = neighbor_road(morphed_pred[i], threshold=2, connectivity=1)
#     morphed_pred[i] = keep_side_connected(morphed_pred[i], connectivity=2)
    pass

# plt.figure(figsize=(1,1))
# plt.imshow(struct, cmap='gray')
# plt.title("Structure element")

img_num = 0
plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(y_train[img_num], cmap='gray')
plt.title("Label")
plt.subplot(132)
plt.imshow(prediction[img_num], cmap='gray')
plt.title("Prediction")
plt.subplot(133)
plt.imshow(morphed_pred[img_num], cmap='gray')
plt.title("Morphed")

f1_pred = 0
f1_morph = 0
for i in range(y_train.shape[0]):
    f1_pred += f1_score(y_train[i].ravel(), prediction[i].ravel())
    f1_morph += f1_score(y_train[i].ravel(), morphed_pred[i].ravel())
f1_pred /= y_train.shape[0]
f1_morph /= y_train.shape[0]

print("F1-score predictions: %f" % f1_pred)
print("F1-score morhpeds:    %f" % f1_morph)
# Out:
# F1-score predictions: 0.685995
# F1-score morhpeds:    0.700377

# %%
# For now, do nothing
pred_label = prediction.astype(int)

# %% [markdown]
# # 4 Create a submission

# %% [markdown]
# ## 4.1 Load the test set

# %%
# Directory name
test_dir = "test_set_images/"

te_image_dir  = sorted(os.listdir(test_dir))

# Number of testing samples
N_te = len(te_image_dir)

# Load the images
image_test = []
for i in range(N_te):
    image_name = os.listdir(test_dir + te_image_dir[i])[0]
    image = mpimg.imread(test_dir + te_image_dir[i] + "/" + image_name)
    
    image_test.append(image)

image_test = np.asarray(image_test)

print(image_test.shape)
# Out:
# (50, 608, 608, 3)

# %% [markdown]
# ## 4.2 Predict the labels

# %%
# Pre-processing; currently nothing
x_test = image_test.copy()
print(x_test.shape)

start = time.time()
kaggle_pred = []
# Because of memory problem, loop on images
for i in range(x_test.shape[0]):
    print("Computing prediction %d/%d" % (i+1, x_test.shape[0]))
    # Extract windows for each patches
    tx_kaggle = image_to_windows(x_test[i], window_size=window_size)
    
    # Create a data loader
    kaggle_dataset = roadDataset(tx_kaggle, train=False)
    kaggle_loader = torch.utils.data.DataLoader(dataset=kaggle_dataset,
                                                batch_size=len(kaggle_dataset), 
                                                shuffle=False)
    
    # Predict the labels
    kaggle_pred.append(predict_label(kaggle_loader, network)[0])

kaggle_pred = np.asarray(kaggle_pred)
print(kaggle_pred.shape)
end = time.time()
print("Predicted test set in %.3f seconds." % (end-start))
# Out:
# (50, 608, 608, 3)
# Computing prediction 1/50
# Computing prediction 2/50
# Computing prediction 3/50
# Computing prediction 4/50
# Computing prediction 5/50
# Computing prediction 6/50
# Computing prediction 7/50
# Computing prediction 8/50
# Computing prediction 9/50
# Computing prediction 10/50
# Computing prediction 11/50
# Computing prediction 12/50
# Computing prediction 13/50
# Computing prediction 14/50
# Computing prediction 15/50
# Computing prediction 16/50
# Computing prediction 17/50
# Computing prediction 18/50
# Computing prediction 19/50
# Computing prediction 20/50
# Computing prediction 21/50
# Computing prediction 22/50
# Computing prediction 23/50
# Computing prediction 24/50
# Computing prediction 25/50
# Computing prediction 26/50
# Computing prediction 27/50
# Computing prediction 28/50
# Computing prediction 29/50
# Computing prediction 30/50
# Computing prediction 31/50
# Computing prediction 32/50
# Computing prediction 33/50
# Computing prediction 34/50
# Computing prediction 35/50
# Computing prediction 36/50
# Computing prediction 37/50
# Computing prediction 38/50
# Computing prediction 39/50
# Computing prediction 40/50
# Computing prediction 41/50
# Computing prediction 42/50
# Computing prediction 43/50
# Computing prediction 44/50
# Computing prediction 45/50
# Computing prediction 46/50
# Computing prediction 47/50
# Computing prediction 48/50
# Computing prediction 49/50
# Computing prediction 50/50
# (50, 38, 38)
# Predicted test set in 249.197 seconds.

# %%
img_num = 0

plt.figure(figsize=(10, 10))
plt.subplot(121)
plt.imshow(x_test[img_num])
plt.title("Image")
plt.subplot(122)
plt.imshow(kaggle_pred[img_num], cmap='gray')
plt.title("Prediction")

# %% [markdown]
# ## 4.3 Post-process the predictions

# %%
# For now, do nothing
kaggle_label = kaggle_pred.astype(int)
print(kaggle_label.shape)
# Out:
# (50, 38, 38)

# %% [markdown]
# ## 4.4 Create a submission file

# %%
def label_to_submission(img_num, label):
    """
    Generate strings from the label image to the .csv submission file
    Input:
        img_num: the number of the image corresponding to the label array
        label: the label array; size:(image_size/PATCH_SIZE, image_size/PATCH_SIZE)
    """
    for j in range(label.shape[0]):
        for i in range(label.shape[1]):
            yield "{:03d}_{}_{},{}".format(img_num, j*PATCH_SIZE, i*PATCH_SIZE, label[i][j])

def create_submission(filename, labels):
    """
    Create a submssion file (.csv) from the given labels
    Input:
        filename: the name to be given to the file (without the .csv)
        labels: the labels array; size:(num_image, image_size/PATCH_SIZE, image_size/PATCH_SIZE)
    """
    filename += ".csv"
    with open(filename, 'w') as f:
        f.write('id,prediction\n')
        for i in range(labels.shape[0]):
            f.writelines('{}\n'.format(s) for s in label_to_submission(i+1, labels[i]))

# %%
create_submission("./submission_files/submission", kaggle_label)
